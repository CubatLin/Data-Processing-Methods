# %% [markdown]
# ### Data Source From : https://github.com/chiluen/Fintech_NanShan

# %%
import pandas as pd 
import numpy as np
import os
path = 'xxx'

CLAIM_ACCT_FIN = pd.read_csv(path+'CLAIM_ACCT_FIN.csv')
COV_ACCT_FIN = pd.read_csv(path+'COV_ACCT_FIN.csv')
CUST_PROPERTY_FIN = pd.read_csv(path+'CUST_PROPERTY.csv')
CUST_RELATION_FIN = pd.read_csv(path+'CUST_RELATION_FIN.csv')

# %%
CLAIM_ACCT_FIN = CLAIM_ACCT_FIN.drop(CLAIM_ACCT_FIN.columns[0],axis=1)

# %%
COV_ACCT_FIN = COV_ACCT_FIN.drop(COV_ACCT_FIN.columns[0],axis=1)

# %%
CUST_PROPERTY_FIN = CUST_PROPERTY_FIN.drop(CUST_PROPERTY_FIN.columns[0],axis=1)

# %%
CUST_RELATION_FIN = CUST_RELATION_FIN.drop(CUST_RELATION_FIN.columns[0],axis=1)

# %% [markdown]
# ### Take a look
# * 理賠檔(CLAIM_ACCT_FIN)
# * 客戶屬性檔(CUST_PROPERTY_FIN)
# * 再購明細檔(COV_ACCT_FIN)
# * 客戶關係檔(CUST_RELATION_FIN)

# %%
#理賠檔
CLAIM_ACCT_FIN.head(5)
# Out:
#    INJURED_RK  Claim_RK  Policy_RK BundleSubtype2 illness_code illness_desc  \
# 0          14      4034      72224        5.N疾病醫療          A09   感染性胃腸炎及大腸炎
# 1          14     62576      72224        4.C重大疾病          N19          腎衰竭
# 2          14     90970      72224        5.N疾病醫療        H26.9          白內障
# 3          14    230243      72224        1.D身故給付          V99       運輸意外事故
# 4          24    157920      91033        5.N疾病醫療        R19.7       腹瀉,未特定
#
#   DiagnosisCode_DESC claim_settle_dt  REIMBURSED_YR_TW  INSURED_RK  \
# 0        01.傳染病和寄生蟲病      2017-03-10           8505.00          14
# 1        14.泌尿生殖系統疾病      2016-08-19           4200.00          14
# 2          07.眼和附器疾病      2016-12-04          29102.85          14
# 3        20.疾病和死亡的外因      2017-03-10        2131618.65          14
# 4     18.症狀異常所見，不可歸類      2017-06-29          32452.35       30372
#
#    POLICY_HOLDER_RK  MATURITY_BENEFICIARY_RK  DEATH_BENEFICIARY_RK
# 0            212635                      NaN                   NaN
# 1            212635                      NaN                   NaN
# 2            212635                      NaN                   NaN
# 3            212635                      NaN                   NaN
# 4             70614                      NaN                   NaN

# %%
#再購明細檔
COV_ACCT_FIN.head(5)
# Out:
#    INSURED_RK  Policy_RK  RIDER_CD payment_period EFFECTIVE_DT SHORT_NAME  \
# 0          20     182361         1             年繳   2018-11-30        CAB
# 1          20     182362         0             年繳   2018-11-30      NPBBR
# 2          20     182362         0             年繳   2018-11-30        PAR
# 3          20     182362         0             年繳   2018-11-30        AMN
# 4          20     182362         0             年繳   2018-11-30       NHSA
#
#   prod_detail2  POLICY_HOLDER_RK  AFYP_NT  MATURITY_BENEFICIARY_RK  \
# 0          AHb            198568   3864.0                      NaN
# 1          AHc            198568   3045.0                 198568.0
# 2          AHc            198568    472.5                 198568.0
# 3          AHc            198568    850.5                 198568.0
# 4          AHa            198568   3675.0                 198568.0
#
#    DEATH_BENEFICIARY_RK
# 0              198568.0
# 1              198568.0
# 2              198568.0
# 3              198568.0
# 4              198568.0

# %%
#客戶屬性檔
CUST_PROPERTY_FIN.head(5)
# Out:
#    CUST_RK  ternure_m  recency_m  SIN  SIN_his  REG  REG_his  ILP  ILP_his  \
# 0       24        201        201    0        0    1        1    0        0
# 1      152        175        175    0        0    1        1    0        0
# 2      155        227        227    0        0    1        1    0        0
# 3      158        165        165    0        0    0        0    0        0
# 4      204        181        181    0        0    1        1    0        0
#
#    AHa  ...  WEALTH_LEVEL  CLIENT_MARITAL  CLIENT_INCOME  DIGI_FLG  TOPCARD  \
# 0    0  ...            W7             NaN              0         0        0
# 1    1  ...            W6             NaN              0         0        0
# 2    1  ...            W7             NaN              0         0        0
# 3    1  ...            W7             NaN              0         0        0
# 4    1  ...            W7             NaN              0         0        0
#
#    GENDER  stick_level2 cust_group2  TOTAL_AUM INSURED_DOB
# 0       1           S10          G4   396720.0  1984-04-04
# 1       1           S10          G4   165870.0  1951-02-26
# 2       1           S10          G4        NaN  1976-07-19
# 3       1           S10          G4    68362.0  1978-12-09
# 4       1           S10          G4    68400.0  1976-09-20
#
# [5 rows x 29 columns]

# %%
#客戶關係檔
CUST_RELATION_FIN.head(5)
# Out:
#    INJURED_RK  householder_RK  Relation_RK            Relation
# 0         238             238       135763  {祖孫、兄弟姊妹}以外的二等以上親屬
# 1         239           16646        16646                  配偶
# 2         242             242        23899               父母/子女
# 3         244             244        23915  {祖孫、兄弟姊妹}以外的二等以上親屬
# 4         245             245         6084  {祖孫、兄弟姊妹}以外的二等以上親屬

# %% [markdown]
# ### Define Y
# * 理賠要保&被保險人在再購檔裡有當要或被保人
# * 意識到保單重要的人有幫自己或幫具可保利益的人投保

# %%
CLAIM_ACCT_FIN.columns
# Out:
# Index(['INJURED_RK', 'Claim_RK', 'Policy_RK', 'BundleSubtype2', 'illness_code',
#        'illness_desc', 'DiagnosisCode_DESC', 'claim_settle_dt',
#        'REIMBURSED_YR_TW', 'INSURED_RK', 'POLICY_HOLDER_RK',
#        'MATURITY_BENEFICIARY_RK', 'DEATH_BENEFICIARY_RK'],
#       dtype='object')

# %%
#理賠要被保set
Y_set = set(list(CLAIM_ACCT_FIN['INSURED_RK'])+ list(CLAIM_ACCT_FIN['POLICY_HOLDER_RK']))

# %%
COV_ACCT_FIN.columns
# Out:
# Index(['INSURED_RK', 'Policy_RK', 'RIDER_CD', 'payment_period', 'EFFECTIVE_DT',
#        'SHORT_NAME', 'prod_detail2', 'POLICY_HOLDER_RK', 'AFYP_NT',
#        'MATURITY_BENEFICIARY_RK', 'DEATH_BENEFICIARY_RK'],
#       dtype='object')

# %%
#被保人RK是否在理賠要被保set
COV_ACCT_FIN['INSURED_RK'].isin(Y_set).value_counts()
# Out:
# False    79181
# True     55291
# Name: INSURED_RK, dtype: int64

# %%
#要保人RK是否在理賠要被保set
COV_ACCT_FIN['POLICY_HOLDER_RK'].isin(Y_set).value_counts()
# Out:
# True     94327
# False    40145
# Name: POLICY_HOLDER_RK, dtype: int64

# %%
COV_ACCT_FIN['Y']=0

# %%
COV_ACCT_FIN.loc[(COV_ACCT_FIN['INSURED_RK'].isin(Y_set)) & (COV_ACCT_FIN['POLICY_HOLDER_RK'].isin(Y_set)),'Y']=1

# %%
COV_ACCT_FIN['Y'].value_counts()
# Out:
# 0    81577
# 1    52895
# Name: Y, dtype: int64

# %%
COV_ACCT_FIN.head(10)
# Out:
#    INSURED_RK  Policy_RK  RIDER_CD payment_period EFFECTIVE_DT SHORT_NAME  \
# 0          20     182361         1             年繳   2018-11-30        CAB
# 1          20     182362         0             年繳   2018-11-30      NPBBR
# 2          20     182362         0             年繳   2018-11-30        PAR
# 3          20     182362         0             年繳   2018-11-30        AMN
# 4          20     182362         0             年繳   2018-11-30       NHSA
# 5          20     182362         0             年繳   2018-11-30        HIR
# 6          20     182362         0             年繳   2018-11-30       ZDDR
# 7          20     182362         1             年繳   2018-11-30     20PCHI
# 8         248      58361         1             年繳   2018-02-22       6WPA
# 9         248     179169         1           躉繳保費   2018-09-29        BVA
#
#   prod_detail2  POLICY_HOLDER_RK    AFYP_NT  MATURITY_BENEFICIARY_RK  \
# 0          AHb            198568     3864.0                      NaN
# 1          AHc            198568     3045.0                 198568.0
# 2          AHc            198568      472.5                 198568.0
# 3          AHc            198568      850.5                 198568.0
# 4          AHa            198568     3675.0                 198568.0
# 5          AHa            198568     1690.5                 198568.0
# 6          AHb            198568    10878.0                 198568.0
# 7          AHa            198568    15582.0                 198568.0
# 8          AHc               248    63000.0                  46032.0
# 9          ILP               248  1050000.0                      NaN
#
#    DEATH_BENEFICIARY_RK  Y
# 0              198568.0  0
# 1              198568.0  0
# 2              198568.0  0
# 3              198568.0  0
# 4              198568.0  0
# 5              198568.0  0
# 6              198568.0  0
# 7              198568.0  0
# 8               46032.0  0
# 9               46032.0  0

# %% [markdown]
# ### 創建一個主檔

# %%
import copy
data = copy.deepcopy(COV_ACCT_FIN)

# %%
data.columns #在購當主檔
# Out:
# Index(['INSURED_RK', 'Policy_RK', 'RIDER_CD', 'payment_period', 'EFFECTIVE_DT',
#        'SHORT_NAME', 'prod_detail2', 'POLICY_HOLDER_RK', 'AFYP_NT',
#        'MATURITY_BENEFICIARY_RK', 'DEATH_BENEFICIARY_RK', 'Y'],
#       dtype='object')

# %%
CLAIM_ACCT_FIN.columns #理賠檔當右檔
# Out:
# Index(['INJURED_RK', 'Claim_RK', 'Policy_RK', 'BundleSubtype2', 'illness_code',
#        'illness_desc', 'DiagnosisCode_DESC', 'claim_settle_dt',
#        'REIMBURSED_YR_TW', 'INSURED_RK', 'POLICY_HOLDER_RK',
#        'MATURITY_BENEFICIARY_RK', 'DEATH_BENEFICIARY_RK'],
#       dtype='object')

# %% [markdown]
# 看一下再購檔過去理賠甚麼商品(被對被);如果值是空的,代表有再購沒理賠
# 1. 他理賠期間不在data範圍
# 2. 沒理賠是新購

# %%
data = pd.merge(data, CLAIM_ACCT_FIN, left_on='INSURED_RK', right_on='INSURED_RK',how='left')

# %% [markdown]
# ### RS Table

# %%
from scipy import stats
def resumetable(df):
    print(f"Dataset Shape: {df.shape}")
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values    
    summary['Uniques'] = df.nunique().values
    summary['First Value'] = df.loc[0].values
    summary['Second Value'] = df.loc[1].values
    summary['Third Value'] = df.loc[2].values

    for name in summary['Name'].value_counts().index:
        summary.loc[summary['Name'] == name, 'Entropy'] = round(stats.entropy(df[name].value_counts(normalize=True), base=2),5) 

    return summary

# %%
resumetable(data)
# Out:
# Dataset Shape: (180267, 24)
#                          Name   dtypes  Missing  Uniques First Value  \
# 0                  INSURED_RK    int64        0    48169          20
# 1                 Policy_RK_x    int64        0    74248      182361
# 2                    RIDER_CD    int64        0        2           1
# 3              payment_period   object        0        5          年繳
# 4                EFFECTIVE_DT   object        0      730  2018-11-30
# 5                  SHORT_NAME   object        0      171         CAB
# 6                prod_detail2   object        0        7         AHb
# 7          POLICY_HOLDER_RK_x    int64        0    39559      198568
# 8                     AFYP_NT  float64        0    16173        3864
# 9   MATURITY_BENEFICIARY_RK_x  float64    60475    29599         NaN
# 10     DEATH_BENEFICIARY_RK_x  float64    46972    30504      198568
# 11                          Y    int64        0        2           0
# 12                 INJURED_RK  float64    91850    16686         NaN
# 13                   Claim_RK  float64    91850    36480         NaN
# 14                Policy_RK_y  float64    91850    19567         NaN
# 15             BundleSubtype2   object    91850        6         NaN
# 16               illness_code   object    91850      329         NaN
# 17               illness_desc   object    91850      333         NaN
# 18         DiagnosisCode_DESC   object    91850       21         NaN
# 19            claim_settle_dt   object    91850      835         NaN
# 20           REIMBURSED_YR_TW  float64    91850    16914         NaN
# 21         POLICY_HOLDER_RK_y  float64    91850    16735         NaN
# 22  MATURITY_BENEFICIARY_RK_y  float64   141590     7555         NaN
# 23     DEATH_BENEFICIARY_RK_y  float64   147755     6316         NaN
#
#    Second Value Third Value   Entropy
# 0            20          20  14.85690
# 1        182362      182362  15.57480
# 2             0           0   0.99376
# 3            年繳          年繳   1.19182
# 4    2018-11-30  2018-11-30   9.26523
# 5         NPBBR         PAR   5.79868
# 6           AHc         AHc   2.52116
# 7        198568      198568  14.51697
# 8          3045       472.5  10.67989
# 9        198568      198568  14.16461
# 10       198568      198568  14.15091
# 11            0           0   0.99645
# 12          NaN         NaN  13.25710
# 13          NaN         NaN  14.69611
# 14          NaN         NaN  13.53732
# 15          NaN         NaN   1.07967
# 16          NaN         NaN   5.32387
# 17          NaN         NaN   5.32544
# 18          NaN         NaN   3.10867
# 19          NaN         NaN   9.10911
# 20          NaN         NaN  12.19505
# 21          NaN         NaN  13.25207
# 22          NaN         NaN  12.16025
# 23          NaN         NaN  11.92530

# %% [markdown]
# ### Feature Engineering: RFM Model
# RFM stands for Receency, Frequency, and Monetary.

# %% [markdown]
# * Recency : 最近一次消費 -> 計算保單再購日期-理賠發生日過了幾個月/天/分鐘/秒

# %%
#看一下join完日期有沒有爆掉
data['claim_settle_dt'].isna().value_counts()
# Out:
# True     91850
# False    88417
# Name: claim_settle_dt, dtype: int64

# %%
#處理日期:用再購日期-理賠發生日
data['EFFECTIVE_DT'] = pd.to_datetime(data['EFFECTIVE_DT'], format='%Y-%m-%d')
data['claim_settle_dt'] = pd.to_datetime(data['claim_settle_dt'], format='%Y-%m-%d')

# %%
data['EffClaim_daydiff'] = data['EFFECTIVE_DT'] - data['claim_settle_dt']

# %%
data.shape
# Out:
# (180267, 25)

# %%
for col in data.columns:
    if'_y' in col:
        data = data.drop(col,axis=1)

# %%
data.columns
# Out:
# Index(['INSURED_RK', 'Policy_RK_x', 'RIDER_CD', 'payment_period',
#        'EFFECTIVE_DT', 'SHORT_NAME', 'prod_detail2', 'POLICY_HOLDER_RK_x',
#        'AFYP_NT', 'MATURITY_BENEFICIARY_RK_x', 'DEATH_BENEFICIARY_RK_x', 'Y',
#        'INJURED_RK', 'Claim_RK', 'BundleSubtype2', 'illness_code',
#        'illness_desc', 'DiagnosisCode_DESC', 'claim_settle_dt',
#        'REIMBURSED_YR_TW', 'EffClaim_daydiff'],
#       dtype='object')

# %%
#簡易feature
data['EffClaim_Daydiff_D'] = data['EffClaim_daydiff'].astype('timedelta64[D]') 
data['EffClaim_Mindiff_M'] = data['EffClaim_daydiff'].astype('timedelta64[m]') 
data['EffClaim_Secdiff_S'] = data['EffClaim_daydiff'].astype('timedelta64[s]')

# %%
#計算一下生效到理賠差幾個月
data['EffClaim_monthdiff']=data['EffClaim_daydiff']/np.timedelta64(1,'M')

# %% [markdown]
# ### EDA

# %%
df0 = data[data['Y']==0]
df1 = data[data['Y']==1]

# %%
rs = resumetable(data)
# Out:
# Dataset Shape: (180267, 25)

# %%
f_list = []
for i in range(len(rs['Name'])):
    if rs['dtypes'][i]=='float64' or rs['dtypes'][i]=='int64':
        f_list.append(rs['Name'][i])

# %%
for feature in f_list:
    sns.set_style('whitegrid')
    plt.figure()
    fig, ax = plt.subplots(1,1,figsize=(16,12))

    sns.distplot(df0[feature], hist=False,label='0')
    sns.distplot(df1[feature], hist=False,label='1')
    plt.xlabel(feature, fontsize=20)
    locs, labels = plt.xticks()
    plt.tick_params(axis='x', which='major', labelsize=15, pad=-6)
    plt.tick_params(axis='y', which='major', labelsize=15)
    plt.show()
# Out:
# C:\Users\w9012219\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\w9012219\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\w9012219\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\w9012219\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
data.head(10)
# Out:
#    INSURED_RK  Policy_RK_x  RIDER_CD payment_period EFFECTIVE_DT SHORT_NAME  \
# 0          20       182361         1             年繳   2018-11-30        CAB
# 1          20       182362         0             年繳   2018-11-30      NPBBR
# 2          20       182362         0             年繳   2018-11-30        PAR
# 3          20       182362         0             年繳   2018-11-30        AMN
# 4          20       182362         0             年繳   2018-11-30       NHSA
# 5          20       182362         0             年繳   2018-11-30        HIR
# 6          20       182362         0             年繳   2018-11-30       ZDDR
# 7          20       182362         1             年繳   2018-11-30     20PCHI
# 8         248        58361         1             年繳   2018-02-22       6WPA
# 9         248       179169         1           躉繳保費   2018-09-29        BVA
#
#   prod_detail2  POLICY_HOLDER_RK_x    AFYP_NT  MATURITY_BENEFICIARY_RK_x  ...  \
# 0          AHb              198568     3864.0                        NaN  ...
# 1          AHc              198568     3045.0                   198568.0  ...
# 2          AHc              198568      472.5                   198568.0  ...
# 3          AHc              198568      850.5                   198568.0  ...
# 4          AHa              198568     3675.0                   198568.0  ...
# 5          AHa              198568     1690.5                   198568.0  ...
# 6          AHb              198568    10878.0                   198568.0  ...
# 7          AHa              198568    15582.0                   198568.0  ...
# 8          AHc                 248    63000.0                    46032.0  ...
# 9          ILP                 248  1050000.0                        NaN  ...
#
#    illness_code  illness_desc  DiagnosisCode_DESC  claim_settle_dt  \
# 0           NaN           NaN                 NaN              NaT
# 1           NaN           NaN                 NaN              NaT
# 2           NaN           NaN                 NaN              NaT
# 3           NaN           NaN                 NaN              NaT
# 4           NaN           NaN                 NaN              NaT
# 5           NaN           NaN                 NaN              NaT
# 6           NaN           NaN                 NaN              NaT
# 7           NaN           NaN                 NaN              NaT
# 8           NaN           NaN                 NaN              NaT
# 9           NaN           NaN                 NaN              NaT
#
#   REIMBURSED_YR_TW EffClaim_daydiff EffClaim_Daydiff_D EffClaim_Mindiff_M  \
# 0              NaN              NaT                NaN                NaN
# 1              NaN              NaT                NaN                NaN
# 2              NaN              NaT                NaN                NaN
# 3              NaN              NaT                NaN                NaN
# 4              NaN              NaT                NaN                NaN
# 5              NaN              NaT                NaN                NaN
# 6              NaN              NaT                NaN                NaN
# 7              NaN              NaT                NaN                NaN
# 8              NaN              NaT                NaN                NaN
# 9              NaN              NaT                NaN                NaN
#
#   EffClaim_Secdiff_S  EffClaim_monthdiff
# 0                NaN                 NaN
# 1                NaN                 NaN
# 2                NaN                 NaN
# 3                NaN                 NaN
# 4                NaN                 NaN
# 5                NaN                 NaN
# 6                NaN                 NaN
# 7                NaN                 NaN
# 8                NaN                 NaN
# 9                NaN                 NaN
#
# [10 rows x 25 columns]

# %%
data['Y'].value_counts()
# Out:
# 1    96458
# 0    83809
# Name: Y, dtype: int64

# %% [markdown]
# #### Frequency: 消費頻率
# * Counts: INSURED_RK (理賠+再購)消費筆數

# %%
data_freqtable = data.groupby(['INSURED_RK']).size().reset_index(name='counts').sort_values(by = 'counts', ascending=False)

# %%
data = data.merge(data_freqtable,on='INSURED_RK',how='left')

# %%
data.shape
# Out:
# (180267, 26)

# %% [markdown]
# #### Monetary: 消費金額
# * REIMBURSED_YR_TW: 理賠金額(歸至該結案年度)
# * AFYP_NT: 保單保費

# %% [markdown]
# 最低之Recency、最高之Frequency、最高之Monetary的高價值客戶，多多進行接觸以及行銷。

# %% [markdown]
# ### Feature Selection

# %%
train_set.columns
# Out:
# Index(['INSURED_RK', 'Policy_RK_x', 'RIDER_CD', 'payment_period',
#        'EFFECTIVE_DT', 'SHORT_NAME', 'prod_detail2', 'POLICY_HOLDER_RK_x',
#        'AFYP_NT', 'MATURITY_BENEFICIARY_RK_x', 'DEATH_BENEFICIARY_RK_x', 'Y',
#        'INJURED_RK', 'Claim_RK', 'BundleSubtype2', 'illness_code',
#        'illness_desc', 'DiagnosisCode_DESC', 'claim_settle_dt',
#        'REIMBURSED_YR_TW', 'EffClaim_daydiff', 'EffClaim_Daydiff_D',
#        'EffClaim_Mindiff_M', 'EffClaim_Secdiff_S', 'EffClaim_monthdiff',
#        'counts', 'counts_Y=0', 'counts_Y=0_pdf', 'counts_Y=1',
#        'counts_Y=1_pdf', 'diff_pdf'],
#       dtype='object')

# %%
resumetable(train_set)
# Out:
# Dataset Shape: (126186, 31)
#                          Name           dtypes  Missing  Uniques  \
# 0                  INSURED_RK            int64        0    35259
# 1                 Policy_RK_x            int64        0    50432
# 2                    RIDER_CD          float64        0        2
# 3              payment_period          float64        0        5
# 4                EFFECTIVE_DT   datetime64[ns]        0      464
# 5                  SHORT_NAME          float64        0       77
# 6                prod_detail2          float64        0        7
# 7          POLICY_HOLDER_RK_x            int64        0    29338
# 8                     AFYP_NT          float64        0    12057
# 9   MATURITY_BENEFICIARY_RK_x          float64    39330    22443
# 10     DEATH_BENEFICIARY_RK_x          float64    32460    23091
# 11                          Y            int64        0        2
# 12                 INJURED_RK          float64        0        5
# 13                   Claim_RK          float64    62962    28035
# 14             BundleSubtype2          float64        0        6
# 15               illness_code          float64        0       58
# 16               illness_desc          float64        0       58
# 17         DiagnosisCode_DESC          float64        0       19
# 18            claim_settle_dt   datetime64[ns]    62962      819
# 19           REIMBURSED_YR_TW          float64    62962    13727
# 20           EffClaim_daydiff  timedelta64[ns]    62962     1511
# 21         EffClaim_Daydiff_D          float64    62962     1511
# 22         EffClaim_Mindiff_M          float64    62962     1511
# 23         EffClaim_Secdiff_S          float64    62962     1511
# 24         EffClaim_monthdiff          float64    62962     1511
# 25                     counts            int64        0       74
# 26                 counts_Y=0            int64        0       74
# 27             counts_Y=0_pdf          float64        0       38
# 28                 counts_Y=1            int64        0       74
# 29             counts_Y=1_pdf          float64        0       72
# 30                   diff_pdf          float64        0       73
#
#             First Value         Second Value          Third Value   Entropy
# 0                 37840                79691                79691  14.43985
# 1                 49514                14772                14772  15.00397
# 2              0.486377             0.596618             0.596618   0.99866
# 3              0.514741             0.514741             0.514741   1.19034
# 4   2016-12-27 00:00:00  2016-12-27 00:00:00  2016-12-27 00:00:00   8.62866
# 5              0.489323             0.543872             0.543872   5.48258
# 6              0.472653             0.683962             0.683962   2.38519
# 7                 37840                79691                79691  14.14066
# 8                607.95                12600                12600  10.43184
# 9                   NaN               224751               224751  13.78852
# 10                  NaN               224751               224751  13.81089
# 11                    1                    1                    1   0.99444
# 12             0.543872             0.543872             0.543872   1.04148
# 13               216022               142989                66723  14.32275
# 14             0.958803             0.959543             0.959543   1.54875
# 15             0.986425             0.977018             0.977018   3.26779
# 16             0.986425             0.977018             0.977018   3.26779
# 17              0.97468             0.977018             0.977018   2.56549
# 18  2017-11-26 00:00:00  2017-05-18 00:00:00  2016-05-30 00:00:00   9.01436
# 19              25313.4              22039.5               8452.5  11.90320
# 20  -334 days +00:00:00  -142 days +00:00:00    211 days 00:00:00  10.00918
# 21                 -334                 -142                  211  10.00918
# 22              -480960              -204480               303840  10.00918
# 23         -2.88576e+07         -1.22688e+07          1.82304e+07  10.00918
# 24             -10.9735             -4.66539              6.93238  10.00918
# 25                    3                    6                    6   4.43620
# 26                    3                    6                    6   4.43620
# 27            0.0781139            0.0837604            0.0837604   4.27428
# 28                    3                    6                    6   4.43620
# 29            0.0680179            0.0856344            0.0856344   4.43343
# 30            -0.010096           0.00187391           0.00187391   4.43480

# %%
Feat_con_col = ['REIMBURSED_YR_TW', 'AFYP_NT', # M
        'EffClaim_Daydiff_D','EffClaim_Mindiff_M', 'EffClaim_Secdiff_S', 'EffClaim_monthdiff', #R
       'counts', #F
       'counts_Y=0', 'counts_Y=0_pdf', 'counts_Y=1',
       'counts_Y=1_pdf', 'diff_pdf' ]

# %%
Feat_str_col = ['SHORT_NAME', 'prod_detail2', 'payment_period','RIDER_CD', #主附約註記
       'INJURED_RK', 'BundleSubtype2', 'illness_code',
       'illness_desc', 'DiagnosisCode_DESC']

# %% [markdown]
# ### Baseline
# * 再購日期切train test

# %%
data = data.sort_values(by = 'EFFECTIVE_DT',ascending=True).reset_index(drop=True)

# %%
data.shape
# Out:
# (180267, 26)

# %%
180267*0.7
# Out:
# 126186.9

# %%
train_set = data[:160000]
test_set = data[160000:]

# %%
train_set
# Out:
#         INSURED_RK  Policy_RK_x  RIDER_CD payment_period EFFECTIVE_DT  \
# 0            37840        49514         0             年繳   2016-12-27
# 1            79691        14772         1             年繳   2016-12-27
# 2            79691        14772         1             年繳   2016-12-27
# 3            73717       172698         1           躉繳保費   2016-12-27
# 4           134664       136547         1             年繳   2016-12-27
# ...            ...          ...       ...            ...          ...
# 159995       36889       177987         0             年繳   2018-08-23
# 159996       54397       147071         0             年繳   2018-08-23
# 159997      211282        10197         0             年繳   2018-08-23
# 159998       36889       177987         0             年繳   2018-08-23
# 159999       36889       177987         0             年繳   2018-08-23
#
#        SHORT_NAME prod_detail2  POLICY_HOLDER_RK_x     AFYP_NT  \
# 0             HIR          AHa               37840     607.950
# 1           EVLRP          ILP               79691   12600.000
# 2           EVLRP          ILP               79691   12600.000
# 3           UISA2          SIN               73717  485350.425
# 4            RLTC          AHd              131135   22596.000
# ...           ...          ...                 ...         ...
# 159995      TSIR2          AHa              220265    2205.000
# 159996       HSDB          AHa               56288     882.000
# 159997        AMN          AHc              211282    1066.800
# 159998       ZDDR          AHb              220265    6930.000
# 159999       NHSA          AHa              220265    3675.000
#
#         MATURITY_BENEFICIARY_RK_x  ...      illness_desc  DiagnosisCode_DESC  \
# 0                             NaN  ...           急性腎炎症候群         14.泌尿生殖系統疾病
# 1                        224751.0  ...  來院接受對工作意外後之檢查及觀察   21.影響健康狀態與保健機構接觸的
# 2                        224751.0  ...  來院接受對工作意外後之檢查及觀察   21.影響健康狀態與保健機構接觸的
# 3                             NaN  ...     其他滑倒、摔倒或絆倒和跌落         20.疾病和死亡的外因
# 4                        131135.0  ...               NaN                 NaN
# ...                           ...  ...               ...                 ...
# 159995                   220265.0  ...               NaN                 NaN
# 159996                        NaN  ...               NaN                 NaN
# 159997                        NaN  ...               NaN                 NaN
# 159998                   220265.0  ...               NaN                 NaN
# 159999                   220265.0  ...               NaN                 NaN
#
#         claim_settle_dt  REIMBURSED_YR_TW EffClaim_daydiff EffClaim_Daydiff_D  \
# 0            2017-11-26          25313.40        -334 days             -334.0
# 1            2017-05-18          22039.50        -142 days             -142.0
# 2            2016-05-30           8452.50         211 days              211.0
# 3            2016-12-31          20921.25          -4 days               -4.0
# 4                   NaT               NaN              NaT                NaN
# ...                 ...               ...              ...                ...
# 159995              NaT               NaN              NaT                NaN
# 159996              NaT               NaN              NaT                NaN
# 159997              NaT               NaN              NaT                NaN
# 159998              NaT               NaN              NaT                NaN
# 159999              NaT               NaN              NaT                NaN
#
#        EffClaim_Mindiff_M EffClaim_Secdiff_S EffClaim_monthdiff  counts
# 0               -480960.0        -28857600.0         -10.973531       3
# 1               -204480.0        -12268800.0          -4.665394       6
# 2                303840.0         18230400.0           6.932381       6
# 3                 -5760.0          -345600.0          -0.131420       1
# 4                     NaN                NaN                NaN       6
# ...                   ...                ...                ...     ...
# 159995                NaN                NaN                NaN       9
# 159996                NaN                NaN                NaN       5
# 159997                NaN                NaN                NaN       7
# 159998                NaN                NaN                NaN       9
# 159999                NaN                NaN                NaN       9
#
# [160000 rows x 26 columns]

# %%
test_set
# Out:
#         INSURED_RK  Policy_RK_x  RIDER_CD payment_period EFFECTIVE_DT  \
# 160000       36889       177987         0             年繳   2018-08-23
# 160001       54397       147071         0             年繳   2018-08-23
# 160002       48223       177631         1             月繳   2018-08-23
# 160003       90938       177928         1             年繳   2018-08-23
# 160004      162739       177737         0             年繳   2018-08-23
# ...            ...          ...       ...            ...          ...
# 180262       95519         2147         1             年繳   2018-12-26
# 180263       95519         2147         1             年繳   2018-12-26
# 180264       95519         2147         1             年繳   2018-12-26
# 180265       53861         2594         1             年繳   2018-12-26
# 180266       87560         2596         1             年繳   2018-12-26
#
#        SHORT_NAME prod_detail2  POLICY_HOLDER_RK_x       AFYP_NT  \
# 160000        HIR          AHa              220265    1690.50000
# 160001      NPBBR          AHc               56288    1134.00000
# 160002    6UISLE3          REG               48223   76879.50732
# 160003     4TISE1          REG               90938  136754.10000
# 160004       N1TR          REG              158379    1239.00000
# ...           ...          ...                 ...           ...
# 180262      ISRWL          REG               95519   79346.40000
# 180263      ISRWL          REG               95519   79346.40000
# 180264      ISRWL          REG               95519   79346.40000
# 180265     2ISWL2          REG               53861  110880.00000
# 180266    2UISWL2          REG               23668  257041.58508
#
#         MATURITY_BENEFICIARY_RK_x  ...   illness_desc  DiagnosisCode_DESC  \
# 160000                   220265.0  ...            NaN                 NaN
# 160001                        NaN  ...            NaN                 NaN
# 160002                    48223.0  ...   牙齒及支持性構造其他疾患           11.消化系統疾病
# 160003                    90938.0  ...         其他外因狀態           99.不知道不想猜
# 160004                   158379.0  ...            NaN                 NaN
# ...                           ...  ...            ...                 ...
# 180262                    95519.0  ...  其他滑倒、摔倒或絆倒和跌落         20.疾病和死亡的外因
# 180263                    95519.0  ...  其他滑倒、摔倒或絆倒和跌落         20.疾病和死亡的外因
# 180264                    95519.0  ...  其他滑倒、摔倒或絆倒和跌落         20.疾病和死亡的外因
# 180265                    53861.0  ...         其他外因狀態           99.不知道不想猜
# 180266                    23668.0  ...             肺炎           10.呼吸系統疾病
#
#         claim_settle_dt  REIMBURSED_YR_TW EffClaim_daydiff EffClaim_Daydiff_D  \
# 160000              NaT               NaN              NaT                NaN
# 160001              NaT               NaN              NaT                NaN
# 160002       2017-11-24            157.50         272 days              272.0
# 160003       2017-12-02          44121.00         264 days              264.0
# 160004              NaT               NaN              NaT                NaN
# ...                 ...               ...              ...                ...
# 180262       2016-03-06           6562.50        1025 days             1025.0
# 180263       2016-03-06          19687.50        1025 days             1025.0
# 180264       2017-02-08           2811.90         686 days              686.0
# 180265       2016-12-14           2399.25         742 days              742.0
# 180266       2017-02-12          13387.50         682 days              682.0
#
#        EffClaim_Mindiff_M EffClaim_Secdiff_S EffClaim_monthdiff  counts
# 160000                NaN                NaN                NaN       9
# 160001                NaN                NaN                NaN       5
# 160002           391680.0         23500800.0           8.936528       1
# 160003           380160.0         22809600.0           8.673689       4
# 160004                NaN                NaN                NaN       7
# ...                   ...                ...                ...     ...
# 180262          1476000.0         88560000.0          33.676256      10
# 180263          1476000.0         88560000.0          33.676256      10
# 180264           987840.0         59270400.0          22.538450      10
# 180265          1068480.0         64108800.0          24.378324      10
# 180266           982080.0         58924800.0          22.407031      18
#
# [20267 rows x 26 columns]

# %% [markdown]
# ### KDE feat

# %%
#不同Y之間的interval不同,要傳入原始df的最大值&最小值
import scipy.stats as st
import math
from collections import defaultdict

xlen =0.5

def feat_fit_func(df,X,X_len): #創造mapping dict
    feat_X = df.sort_values(by=[X]).reset_index(drop=True)[X].to_numpy()
    interval_n = math.ceil((feat_X.max()-feat_X.min())/X_len) #區間數
    feat_Xmin = feat_X.min() #最小值
    
    print("interval_n: ",interval_n)
    print("feat_Xmin: ",feat_Xmin)

    for i in range(interval_n,-1,-1):
        feat_X[(feat_Xmin + (i)*X_len <= feat_X) &\
               (feat_X < feat_Xmin + (i+1)*X_len) ] = feat_Xmin + (i+1)*X_len #向右靠齊
    unique, counts = np.unique(feat_X, return_counts=True)
    counts_propotion = counts/len(feat_X)

    my_dict=defaultdict(int)
    for i in range(len(unique)):
        my_dict[unique[i]]=counts_propotion[i]

    return my_dict

# %%
train_set.columns
# Out:
# Index(['INSURED_RK', 'Policy_RK_x', 'RIDER_CD', 'payment_period',
#        'EFFECTIVE_DT', 'SHORT_NAME', 'prod_detail2', 'POLICY_HOLDER_RK_x',
#        'AFYP_NT', 'MATURITY_BENEFICIARY_RK_x', 'DEATH_BENEFICIARY_RK_x', 'Y',
#        'INJURED_RK', 'Claim_RK', 'BundleSubtype2', 'illness_code',
#        'illness_desc', 'DiagnosisCode_DESC', 'claim_settle_dt',
#        'REIMBURSED_YR_TW', 'EffClaim_daydiff', 'EffClaim_Daydiff_D',
#        'EffClaim_Mindiff_M', 'EffClaim_Secdiff_S', 'EffClaim_monthdiff',
#        'counts'],
#       dtype='object')

# %%
counts_dict_0 = feat_fit_func(train_set[train_set['Y']==0].reset_index(drop=True),'counts',xlen)
counts_dict_1 = feat_fit_func(train_set[train_set['Y']==1].reset_index(drop=True),'counts',xlen)
# Out:
# interval_n:  548
# feat_Xmin:  1
# interval_n:  548
# feat_Xmin:  1

# %%
#fit 固定範圍,transform就可以直接用
def feat_transform_func(df,X,X_len,fit_dict): #放入df & mapping dict, Return Feat pdf
    feat_X = copy.deepcopy(df[X]).to_numpy()
    
    #區間+1才會是原長度
    interval_n = math.ceil((max(list(fit_dict.keys())) - min(list(fit_dict.keys())) )/X_len)+1 
    feat_Xmin = min(list(fit_dict.keys()))-X_len #向右靠齊所以要往前推一格

    for i in range(interval_n,-1,-1):
        feat_X[(feat_Xmin + (i)*X_len <= feat_X) &\
               (feat_X < feat_Xmin + (i+1)*X_len) ] = feat_Xmin + (i+1)*X_len #向右靠齊
    
    return feat_X

# %%
#把feature標準化    
train_set['counts_Y=0'] = feat_transform_func(train_set,'counts',xlen,counts_dict_0)
#把feature做mapping pdf
train_set['counts_Y=0_pdf'] = [counts_dict_0[i] for i in train_set['counts_Y=0']]
# Out:
# C:\Users\w9012219\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\w9012219\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#把feature標準化    
train_set['counts_Y=1'] = feat_transform_func(train_set,'counts',xlen,counts_dict_1)
#把feature做mapping pdf
train_set['counts_Y=1_pdf'] = [counts_dict_1[i] for i in train_set['counts_Y=1']]
# Out:
# C:\Users\w9012219\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\w9012219\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#把feature標準化    
test_set['counts_Y=0'] = feat_transform_func(test_set,'counts',xlen,counts_dict_0)
#把feature做mapping pdf
test_set['counts_Y=0_pdf'] = [counts_dict_0[i] for i in test_set['counts_Y=0']]
# Out:
# C:\Users\w9012219\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\w9012219\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#把feature標準化    
test_set['counts_Y=1'] = feat_transform_func(test_set,'counts',xlen,counts_dict_1)
#把feature做mapping pdf
test_set['counts_Y=1_pdf'] = [counts_dict_1[i] for i in test_set['counts_Y=1']]
# Out:
# C:\Users\w9012219\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\w9012219\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
train_set['diff_pdf'] = train_set['counts_Y=1_pdf'] - train_set['counts_Y=0_pdf']
test_set['diff_pdf'] = test_set['counts_Y=1_pdf'] - test_set['counts_Y=0_pdf']
# Out:
# C:\Users\w9012219\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\w9012219\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# #### Target Encode

# %%
from category_encoders.target_encoder import TargetEncoder
Tar_enc  = TargetEncoder(cols = Feat_str_col,return_df=True, min_samples_leaf=150, smoothing=0.5).fit(train_set, train_set['Y'])

# %%
train_set = Tar_enc.transform(train_set)

# %%
test_set = Tar_enc.transform(test_set)

# %% [markdown]
# # XGB

# %%
import xgboost as xgb

# %%
resumetable(train_set)
# Out:
# Dataset Shape: (160000, 31)
#                          Name           dtypes  Missing  Uniques  \
# 0                  INSURED_RK            int64        0    43283
# 1                 Policy_RK_x            int64        0    65193
# 2                    RIDER_CD          float64        0        2
# 3              payment_period          float64        0        5
# 4                EFFECTIVE_DT   datetime64[ns]        0      605
# 5                  SHORT_NAME          float64        0       88
# 6                prod_detail2          float64        0        7
# 7          POLICY_HOLDER_RK_x            int64        0    35536
# 8                     AFYP_NT          float64        0    14572
# 9   MATURITY_BENEFICIARY_RK_x          float64    53050    26775
# 10     DEATH_BENEFICIARY_RK_x          float64    42425    27632
# 11                          Y            int64        0        2
# 12                 INJURED_RK          float64        0        8
# 13                   Claim_RK          float64    80333    33831
# 14             BundleSubtype2          float64        0        6
# 15               illness_code          float64        0       64
# 16               illness_desc          float64        0       64
# 17         DiagnosisCode_DESC          float64        0       21
# 18            claim_settle_dt   datetime64[ns]    80333      832
# 19           REIMBURSED_YR_TW          float64    80333    15963
# 20           EffClaim_daydiff  timedelta64[ns]    80333     1644
# 21         EffClaim_Daydiff_D          float64    80333     1644
# 22         EffClaim_Mindiff_M          float64    80333     1644
# 23         EffClaim_Secdiff_S          float64    80333     1644
# 24         EffClaim_monthdiff          float64    80333     1644
# 25                     counts            int64        0       74
# 26                 counts_Y=0            int64        0       74
# 27             counts_Y=0_pdf          float64        0       40
# 28                 counts_Y=1            int64        0       74
# 29             counts_Y=1_pdf          float64        0       69
# 30                   diff_pdf          float64        0       71
#
#             First Value         Second Value          Third Value   Entropy
# 0                 37840                79691                79691  14.71390
# 1                 49514                14772                14772  15.38297
# 2              0.473098             0.600731             0.600731   0.99532
# 3              0.513728             0.513728             0.513728   1.18983
# 4   2016-12-27 00:00:00  2016-12-27 00:00:00  2016-12-27 00:00:00   9.01434
# 5              0.471052              0.54205              0.54205   5.64152
# 6              0.466593             0.703353             0.703353   2.49412
# 7                 37840                79691                79691  14.38334
# 8                607.95                12600                12600  10.61791
# 9                   NaN               224751               224751  14.02938
# 10                  NaN               224751               224751  14.04257
# 11                    1                    1                    1   0.99489
# 12              0.54205              0.54205              0.54205   1.06782
# 13               216022               142989                66723  14.59186
# 14             0.953685              0.95691              0.95691   1.53997
# 15                0.988             0.976127             0.976127   3.27949
# 16                0.988             0.976127             0.976127   3.27949
# 17             0.970526             0.976127             0.976127   2.54950
# 18  2017-11-26 00:00:00  2017-05-18 00:00:00  2016-05-30 00:00:00   9.08721
# 19              25313.4              22039.5               8452.5  12.12013
# 20  -334 days +00:00:00  -142 days +00:00:00    211 days 00:00:00  10.24675
# 21                 -334                 -142                  211  10.24675
# 22              -480960              -204480               303840  10.24675
# 23         -2.88576e+07         -1.22688e+07          1.82304e+07  10.24675
# 24             -10.9735             -4.66539              6.93238  10.24675
# 25                    3                    6                    6   4.44822
# 26                    3                    6                    6   4.44822
# 27            0.0810678            0.0850939            0.0850939   4.30299
# 28                    3                    6                    6   4.44822
# 29            0.0696776            0.0869731            0.0869731   4.44170
# 30           -0.0113902           0.00187917           0.00187917   4.44342

# %%
dtrain = xgb.DMatrix(train_set[Feat_con_col+Feat_str_col],label=train_set['Y'])

# %% [markdown]
# "eval_metric":"auc" why

# %%
param = {#'max_depth': 6,
         'learning_rate ': 0.005,
         #'silent': 1,
         'objective': 'binary:logistic',
         "eval_metric":"auc" 
         #"scale_pos_weight":10,
         #"subsample":0.9,
         #"min_child_weight":5,
          }

# %%
cv_res= xgb.cv(param,
               dtrain,
               num_boost_round=1000,#830
               early_stopping_rounds=6,
               nfold=3, metrics='logloss',show_stdv=True)

print(cv_res)
# Out:
#      train-logloss-mean  train-logloss-std  test-logloss-mean  \
# 0              0.511810           0.000278           0.512077
# 1              0.413913           0.000294           0.414439
# 2              0.355092           0.000311           0.355917
# 3              0.318092           0.000407           0.319145
# 4              0.294455           0.000416           0.295844
# ..                  ...                ...                ...
# 319            0.170105           0.000629           0.222282
# 320            0.170021           0.000609           0.222297
# 321            0.169872           0.000674           0.222309
# 322            0.169642           0.000624           0.222316
# 323            0.169496           0.000657           0.222281
#
#      test-logloss-std
# 0            0.000099
# 1            0.000246
# 2            0.000341
# 3            0.000398
# 4            0.000627
# ..                ...
# 319          0.002304
# 320          0.002310
# 321          0.002328
# 322          0.002315
# 323          0.002379
#
# [324 rows x 4 columns]

# %%
#cv_res.shape[0]為最佳迭代次數
bst = xgb.train(param,dtrain,num_boost_round=cv_res.shape[0])

# %%
dtest= xgb.DMatrix(test_set[Feat_con_col+Feat_str_col])

# %%
y_pred_prob = bst.predict(dtest)

# %%
test_set['y_pred_prob']=y_pred_prob

# %%
test_set['y_pred_prob'] = np.where(test_set['y_pred_prob']>0.6,1,0)

# %% [markdown]
# ### Evaluation

# %%
xgb.plot_importance(bst)

# %%
from sklearn import metrics
pre = metrics.precision_score(test_set['Y'],test_set['y_pred_prob'])
re = metrics.recall_score(test_set['Y'],test_set['y_pred_prob'])
f1 = metrics.f1_score(test_set['Y'],test_set['y_pred_prob'])
print('Precision:',pre,'\n'
     'Recall:',re,'\n'
     'F1:',f1)
# Out:
# Precision: 0.9378017935157508
# Recall: 0.8383350462487154
# F1: 0.8852832645973518
