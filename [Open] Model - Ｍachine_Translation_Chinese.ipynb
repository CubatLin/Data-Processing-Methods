# %% [markdown]
# <a href="https://colab.research.google.com/github/CubatLin/Data-Processing-Methods/blob/master/%5BOpen%5D%20Model%20-%20%EF%BC%ADachine_Translation_Chinese.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### kashgari

# %%
# !pip install kashgari
# Out:
# Collecting kashgari
#   Downloading https://files.pythonhosted.org/packages/89/d6/c22b19e11ebb5d1fbb9b37db67c1350f97fd1be1a295821cc57fb0775823/kashgari-2.0.1-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 5.1MB/s
# Requirement already satisfied: scikit-learn>=0.21.1 in /usr/local/lib/python3.7/dist-packages (from kashgari) (0.22.2.post1)
# Collecting tensorflow-addons
#   Downloading https://files.pythonhosted.org/packages/74/e3/56d2fe76f0bb7c88ed9b2a6a557e25e83e252aec08f13de34369cd850a0b/tensorflow_addons-0.12.1-cp37-cp37m-manylinux2010_x86_64.whl (703kB)
#      |████████████████████████████████| 706kB 24.7MB/s
# Collecting gensim>=3.8.1
#   Downloading https://files.pythonhosted.org/packages/5c/4e/afe2315e08a38967f8a3036bbe7e38b428e9b7a90e823a83d0d49df1adf5/gensim-3.8.3-cp37-cp37m-manylinux1_x86_64.whl (24.2MB)
#      |████████████████████████████████| 24.2MB 1.5MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kashgari) (4.41.1)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from kashgari) (1.19.5)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from kashgari) (1.1.5)
# Collecting bert4keras>=0.9.1
#   Downloading https://files.pythonhosted.org/packages/60/87/31f8e75459ca7c8137d7d2c9225fe36b42112ed46601c4139f604bf2b2ca/bert4keras-0.10.3.tar.gz (46kB)
#      |████████████████████████████████| 51kB 4.1MB/s
# Requirement already satisfied: tensorflow>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from kashgari) (2.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.1->kashgari) (1.0.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.1->kashgari) (1.4.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->kashgari) (2.7.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim>=3.8.1->kashgari) (4.2.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim>=3.8.1->kashgari) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.1->kashgari) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.1->kashgari) (2018.9)
# Collecting keras<=2.3.1
#   Downloading https://files.pythonhosted.org/packages/ad/fd/6bfe87920d7f4fd475acd28500a42482b6b84479832bdc0fe9e589a60ceb/Keras-2.3.1-py2.py3-none-any.whl (377kB)
#      |████████████████████████████████| 378kB 50.8MB/s
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->kashgari) (1.32.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->kashgari) (0.2.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->kashgari) (0.36.2)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->kashgari) (2.4.1)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->kashgari) (3.7.4.3)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->kashgari) (2.4.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->kashgari) (3.12.4)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->kashgari) (1.12.1)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->kashgari) (0.3.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->kashgari) (3.3.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->kashgari) (1.6.3)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->kashgari) (1.1.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->kashgari) (1.1.2)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->kashgari) (0.10.0)
# Requirement already satisfied: h5py~=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->kashgari) (2.10.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.1.0->kashgari) (1.12)
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 4.2MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras<=2.3.1->bert4keras>=0.9.1->kashgari) (3.13)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (1.27.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (54.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (0.4.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (1.8.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (4.7.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (3.7.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (3.0.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (3.4.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=2.1.0->kashgari) (3.1.0)
# Building wheels for collected packages: bert4keras
#   Building wheel for bert4keras (setup.py) ... done
#   Created wheel for bert4keras: filename=bert4keras-0.10.3-cp37-none-any.whl size=44302 sha256=c0d7bb67bd1a826baff58ab3872d515e62b5c03b178a529cc3a00aaa09c7890e
#   Stored in directory: /root/.cache/pip/wheels/29/23/c0/d9b4f0fe1b6bbb8903f5f4cc4f922d34d5b76140e8058db42c
# Successfully built bert4keras
# Installing collected packages: tensorflow-addons, gensim, keras-applications, keras, bert4keras, kashgari
#   Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed bert4keras-0.10.3 gensim-3.8.3 kashgari-2.0.1 keras-2.3.1 keras-applications-1.0.8 tensorflow-addons-0.12.1

# %%
from kashgari.corpus import ChineseDailyNerCorpus

train_x, train_y = ChineseDailyNerCorpus.load_data('train')
valid_x, valid_y = ChineseDailyNerCorpus.load_data('validate')
test_x, test_y  = ChineseDailyNerCorpus.load_data('test')

def load_data2set(set_x, set_y, max_num = 50000):
      data_set = []
      idx = 0
      sent_text,sent_slot="",""
      for label,ans in zip(set_x,set_y):
          idx+=1
          if idx > max_num and max_num !=-1:
            break
          sent_text = " ".join(label)
          sent_slot = " ".join(ans)
          data_set.append([sent_text,sent_slot])

      print("data_set: ",data_set[:50])
      return data_set
print(f"train data count: {len(train_x)}")
print(f"validate data count: {len(valid_x)}")
print(f"test data count: {len(test_x)}")


load_data2set(train_x[:10],train_y[:10])
# Out:
# Downloading data from http://s3.bmio.net/kashgari/china-people-daily-ner-corpus.tar.gz
# 2449408/2443473 [==============================] - 2s 1us/step
# 2021-03-15 06:34:11,526 [DEBUG] kashgari - loaded 20864 samples from /root/.kashgari/datasets/china-people-daily-ner-corpus/example.train. Sample:
# x[0]: ['芬', '兰', '人', '口', '联', '盟', '最', '近', '在', '公', '布', '以', '上', '消', '息', '时', '说', '，', '不', '育', '症', '在', '芬', '兰', '十', '分', '普', '遍', '，', '大', '约', '1', '／', '1', '0', '的', '育', '龄', '夫', '妇', '因', '女', '方', '输', '卵', '管', '堵', '塞', '或', '男', '方', '精', '子', '稀', '少', '而', '出', '现', '不', '育', '状', '况', '。']
# y[0]: ['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 2021-03-15 06:34:11,618 [DEBUG] kashgari - loaded 2318 samples from /root/.kashgari/datasets/china-people-daily-ner-corpus/example.dev. Sample:
# x[0]: ['1', '、', '中', '国', '作', '协', '和', '现', '代', '文', '学', '馆', '负', '责', '人', '在', '巴', '金', '家', '中', '介', '绍', '文', '学', '馆', '新', '馆', '设', '计', '模', '型', '。']
# y[0]: ['O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 2021-03-15 06:34:11,790 [DEBUG] kashgari - loaded 4636 samples from /root/.kashgari/datasets/china-people-daily-ner-corpus/example.test. Sample:
# x[0]: ['农', '历', '正', '月', '初', '一', '，', '刘', '德', '意', '又', '领', '着', '儿', '子', '，', '提', '着', '杀', '好', '的', '鸡', '、', '鱼', '到', '余', '长', '生', '家', '拜', '年', '，', '认', '“', '穷', '亲', '”', '，', '长', '生', '感', '动', '得', '不', '知', '说', '什', '么', '好', '。']
# y[0]: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# train data count: 20864
# validate data count: 2318
# test data count: 4636
# data_set:  [['芬 兰 人 口 联 盟 最 近 在 公 布 以 上 消 息 时 说 ， 不 育 症 在 芬 兰 十 分 普 遍 ， 大 约 1 ／ 1 0 的 育 龄 夫 妇 因 女 方 输 卵 管 堵 塞 或 男 方 精 子 稀 少 而 出 现 不 育 状 况 。', 'B-ORG I-ORG I-ORG I-ORG I-ORG I-ORG O O O O O O O O O O O O O O O O B-LOC I-LOC O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O'], ['为 此 ， 我 们 召 开 了 全 国 税 务 局 长 会 议 ， 决 定 采 取 以 下 十 个 方 面 的 措 施 ： 一 是 抓 紧 清 理 漏 征 漏 管 户 ； 二 是 加 强 重 点 税 源 的 专 项 检 查 ； 三 是 进 一 步 加 强 稽 查 队 伍 建 设 ， 充 分 发 挥 稽 查 职 能 作 用 ； 四 是 大 力 清 理 欠 税 ； 五 是 严 格 期 初 库 存 抵 扣 ； 六 是 严 格 把 关 ， 加 快 免 抵 扣 ； 七 是 认 真 落 实 对 1 8 0 万 以 下 增 值 税 一 般 纳 税 人 的 新 政 策 ； 八 是 国 、 地 税 机 关 密 切 合 作 ， 管 好 交 通 运 输 业 普 通 发 票 ； 九 是 加 强 对 加 油 站 、 出 租 车 的 税 收 征 管 ； 十 是 根 据 税 源 结 构 变 化 ， 及 时 调 整 征 管 力 量 ， 确 保 新 的 经 济 增 长 点 同 时 也 成 为 新 的 税 收 增 长 点 。', 'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O'], ['通 过 市 场 调 研 ， 黄 作 兴 发 现 高 温 高 压 高 性 能 的 金 属 硬 密 封 蝶 阀 是 当 今 世 界 阀 门 的 发 展 方 向 ， 也 是 阀 门 市 场 的 迫 切 需 求 ； 同 时 他 也 了 解 到 ， 目 前 国 内 外 生 产 的 传 统 金 属 密 封 结 构 的 蝶 阀 ， 尚 存 在 许 多 造 成 泄 漏 的 潜 在 因 素 。', 'O O O O O O O B-PER I-PER I-PER O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O'], ['尽 早 加 入 世 贸 组 织 对 中 国 来 说 也 将 是 有 益 的 。', 'O O O O B-ORG I-ORG I-ORG I-ORG O B-LOC I-LOC O O O O O O O O O'], ['而 在 尚 不 富 裕 的 山 东 省 郓 城 县 ， 就 有 一 位 着 意 为 下 岗 工 人 营 造 再 就 业 绿 地 的 人 。', 'O O O O O O O B-LOC I-LOC I-LOC B-LOC I-LOC I-LOC O O O O O O O O O O O O O O O O O O O O O O'], ['苏 南 各 级 政 府 积 极 创 造 公 平 的 政 策 和 市 场 环 境 ， 激 发 私 营 企 业 活 力 。', 'B-LOC O O O O O O O O O O O O O O O O O O O O O O O O O O O O O'], ['在 许 多 人 的 印 象 里 ， 只 要 到 了 医 院 就 会 有 血 液 ， 就 可 以 输 血 ， 可 现 实 并 非 如 此 。', 'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O'], ['他 说 ， 意 中 两 国 关 系 很 好 ， 意 大 利 政 府 把 发 展 对 华 关 系 摆 在 首 位 ， 近 几 年 来 加 深 了 同 中 国 的 关 系 ， 特 别 是 经 济 关 系 。', 'O O O B-LOC B-LOC O O O O O O O B-LOC I-LOC I-LOC O O O O O O B-LOC O O O O O O O O O O O O O O O B-LOC I-LOC O O O O O O O O O O O O'], ['本 报 东 京 6 月 2 4 日 电 记 者 于 青 报 道 ： 东 京 外 汇 市 场 日 元 对 美 元 汇 率 今 天 继 续 急 剧 下 跌 ， 收 盘 时 为 1 4 0 ． 3 4 日 元 换 1 美 元 ， 比 昨 天 下 跌 2 ． 6 0 日 元 。', 'O O B-LOC I-LOC O O O O O O O O B-PER I-PER O O O B-LOC I-LOC O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O'], ['中 国 民 主 促 进 会 （ 民 主 党 派 简 介 ）', 'B-ORG I-ORG I-ORG I-ORG I-ORG I-ORG I-ORG O O O O O O O O']]
# [['芬 兰 人 口 联 盟 最 近 在 公 布 以 上 消 息 时 说 ， 不 育 症 在 芬 兰 十 分 普 遍 ， 大 约 1 ／ 1 0 的 育 龄 夫 妇 因 女 方 输 卵 管 堵 塞 或 男 方 精 子 稀 少 而 出 现 不 育 状 况 。',
#   'B-ORG I-ORG I-ORG I-ORG I-ORG I-ORG O O O O O O O O O O O O O O O O B-LOC I-LOC O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O'],
#  ['为 此 ， 我 们 召 开 了 全 国 税 务 局 长 会 议 ， 决 定 采 取 以 下 十 个 方 面 的 措 施 ： 一 是 抓 紧 清 理 漏 征 漏 管 户 ； 二 是 加 强 重 点 税 源 的 专 项 检 查 ； 三 是 进 一 步 加 强 稽 查 队 伍 建 设 ， 充 分 发 挥 稽 查 职 能 作 用 ； 四 是 大 力 清 理 欠 税 ； 五 是 严 格 期 初 库 存 抵 扣 ； 六 是 严 格 把 关 ， 加 快 免 抵 扣 ； 七 是 认 真 落 实 对 1 8 0 万 以 下 增 值 税 一 般 纳 税 人 的 新 政 策 ； 八 是 国 、 地 税 机 关 密 切 合 作 ， 管 好 交 通 运 输 业 普 通 发 票 ； 九 是 加 强 对 加 油 站 、 出 租 车 的 税 收 征 管 ； 十 是 根 据 税 源 结 构 变 化 ， 及 时 调 整 征 管 力 量 ， 确 保 新 的 经 济 增 长 点 同 时 也 成 为 新 的 税 收 增 长 点 。',
#   'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O'],
#  ['通 过 市 场 调 研 ， 黄 作 兴 发 现 高 温 高 压 高 性 能 的 金 属 硬 密 封 蝶 阀 是 当 今 世 界 阀 门 的 发 展 方 向 ， 也 是 阀 门 市 场 的 迫 切 需 求 ； 同 时 他 也 了 解 到 ， 目 前 国 内 外 生 产 的 传 统 金 属 密 封 结 构 的 蝶 阀 ， 尚 存 在 许 多 造 成 泄 漏 的 潜 在 因 素 。',
#   'O O O O O O O B-PER I-PER I-PER O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O'],
#  ['尽 早 加 入 世 贸 组 织 对 中 国 来 说 也 将 是 有 益 的 。',
#   'O O O O B-ORG I-ORG I-ORG I-ORG O B-LOC I-LOC O O O O O O O O O'],
#  ['而 在 尚 不 富 裕 的 山 东 省 郓 城 县 ， 就 有 一 位 着 意 为 下 岗 工 人 营 造 再 就 业 绿 地 的 人 。',
#   'O O O O O O O B-LOC I-LOC I-LOC B-LOC I-LOC I-LOC O O O O O O O O O O O O O O O O O O O O O O'],
#  ['苏 南 各 级 政 府 积 极 创 造 公 平 的 政 策 和 市 场 环 境 ， 激 发 私 营 企 业 活 力 。',
#   'B-LOC O O O O O O O O O O O O O O O O O O O O O O O O O O O O O'],
#  ['在 许 多 人 的 印 象 里 ， 只 要 到 了 医 院 就 会 有 血 液 ， 就 可 以 输 血 ， 可 现 实 并 非 如 此 。',
#   'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O'],
#  ['他 说 ， 意 中 两 国 关 系 很 好 ， 意 大 利 政 府 把 发 展 对 华 关 系 摆 在 首 位 ， 近 几 年 来 加 深 了 同 中 国 的 关 系 ， 特 别 是 经 济 关 系 。',
#   'O O O B-LOC B-LOC O O O O O O O B-LOC I-LOC I-LOC O O O O O O B-LOC O O O O O O O O O O O O O O O B-LOC I-LOC O O O O O O O O O O O O'],
#  ['本 报 东 京 6 月 2 4 日 电 记 者 于 青 报 道 ： 东 京 外 汇 市 场 日 元 对 美 元 汇 率 今 天 继 续 急 剧 下 跌 ， 收 盘 时 为 1 4 0 ． 3 4 日 元 换 1 美 元 ， 比 昨 天 下 跌 2 ． 6 0 日 元 。',
#   'O O B-LOC I-LOC O O O O O O O O B-PER I-PER O O O B-LOC I-LOC O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O'],
#  ['中 国 民 主 促 进 会 （ 民 主 党 派 简 介 ）',
#   'B-ORG I-ORG I-ORG I-ORG I-ORG I-ORG I-ORG O O O O O O O O']]

# %% [markdown]
# ## 機器翻譯
# https://ithelp.ithome.com.tw/articles/10194403

# %%
'''https://github.com/keras-team/keras/blob/master/examples/lstm_seq2seq.py
Sequence to sequence example in Keras (character-level).
# Data download
English to French sentence pairs.
http://www.manythings.org/anki/fra-eng.zip
'''
from __future__ import print_function

from keras.models import Model
from keras.layers import Input, LSTM, Dense
import numpy as np

# 參數設定
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 32  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.

# 設定訓練資料檔路徑
#data_path = 'fra-eng/fra.txt'
data_path = '/content/drive/MyDrive/Python/Shopee Code League 2021/#2 Address Element Extraction/cmn.txt' 

# 讀取資料檔，並將所有單字整理為字典，分別為英文及中文字典，注意，英文為字母的集合，非單字(Word)
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()

# %%
lines = open(data_path, encoding ='utf8').read().split('\n')

# %%
lines[0:4]
# Out:
# ['Hi.\t嗨。', 'Hi.\t你好。', 'Run.\t你用跑的。', 'Wait!\t等等！']

# %%
lines[3].split('\t')
# Out:
# ['Wait!', '等等！']

# %%
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text = line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    #把所有字弄成一個set
    #英文要split
    #for char in input_text.split(' '):
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

# %%
print(input_texts[0:3])
print(target_texts[0:3])
# Out:
# ['Hi.', 'Hi.', 'Run.']
# ['\t嗨。\n', '\t你好。\n', '\t你用跑的。\n']

# %%
# 字典排序            
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
# 計算編碼器、解碼器的最大長度
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 73
# Number of unique output tokens: 2640
# Max sequence length for inputs: 31
# Max sequence length for outputs: 22

# %%
# 以dict儲存字典單字及序號
input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

#one hot
# 設定編碼器、解碼器input起始值(均為0矩陣)
encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

# %%
print(input_texts[3])
# Out:
# Wait!

# %%
print(target_texts[3])
# Out:
# 	等等！

# %%
# 設定 encoder_input、decoder_input對應的順序    
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
#    for t, char in enumerate(input_text.split(' ')): #遍歷所有單詞，做成input對應
    for t, char in enumerate(input_text): #遍歷所有單詞，做成input對應
        print(char)
        encoder_input_data[i, t, input_token_index[char]] = 1.
#    for t, char in enumerate(target_text.split(' ')):
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# v
# e
# r
# y
#
# d
# a
# y
# .
# H
# e
#
# d
# o
# e
# s
# n
# '
# t
#
# k
# n
# o
# w
#
# E
# n
# g
# l
# i
# s
# h
#
# a
# t
#
# a
# l
# l
# .
# H
# e
#
# d
# r
# a
# n
# k
#
# t
# h
# r
# e
# e
#
# b
# o
# t
# t
# l
# e
# s
#
# o
# f
#
# b
# e
# e
# r
# .
# H
# e
#
# d
# r
# o
# p
# p
# e
# d
#
# i
# n
#
# a
# t
#
# t
# h
# e
#
# b
# o
# o
# k
# s
# t
# o
# r
# e
# .
# H
# e
#
# e
# a
# r
# n
# s
#
# h
# i
# s
#
# l
# i
# v
# i
# n
# g
#
# b
# y
#
# w
# r
# i
# t
# i
# n
# g
# .
# H
# e
#
# f
# a
# i
# l
# e
# d
#
# t
# o
#
# a
# n
# s
# w
# e
# r
#
# t
# h
# e
#
# l
# e
# t
# t
# e
# r
# .
# H
# e
#
# f
# a
# i
# l
# e
# d
#
# t
# o
#
# f
# o
# l
# l
# o
# w
#
# o
# u
# r
#
# a
# d
# v
# i
# c
# e
# .
# H
# e
#
# f
# e
# l
# t
#
# h
# i
# s
#
# h
# e
# a
# r
# t
#
# b
# e
# a
# t
# i
# n
# g
#
# f
# a
# s
# t
# .
# H
# e
#
# f
# l
# a
# t
# l
# y
#
# r
# e
# f
# u
# s
# e
# d
#
# t
# o
#
# l
# e
# t
#
# m
# e
#
# i
# n
# .
# H
# e
#
# g
# a
# v
# e
#
# u
# s
#
# t
# h
# e
#
# s
# i
# g
# n
# a
# l
#
# t
# o
#
# b
# e
# g
# i
# n
# .
# H
# e
#
# g
# a
# v
# e
#
# u
# s
#
# t
# h
# e
#
# s
# i
# g
# n
# a
# l
#
# t
# o
#
# b
# e
# g
# i
# n
# .
# H
# e
#
# g
# o
# e
# s
#
# t
# o
#
# L
# o
# n
# d
# o
# n
#
# o
# n
# c
# e
#
# a
#
# m
# o
# n
# t
# h
# .
# H
# e
#
# g
# o
# t
#
# o
# f
# f
#
# a
# t
#
# t
# h
# e
#
# n
# e
# x
# t
#
# s
# t
# a
# t
# i
# o
# n
# .
# H
# e
#
# g
# o
# t
#
# t
# h
# r
# o
# w
# n
#
# o
# u
# t
#
# o
# f
#
# t
# h
# e
#
# h
# o
# u
# s
# e
# .
# H
# e
#
# g
# r
# e
# w
#
# u
# p
#
# i
# n
#
# a
#
# l
# i
# t
# t
# l
# e
#
# v
# i
# l
# l
# a
# g
# e
# .
# H
# e
#
# h
# a
# d
#
# d
# e
# c
# i
# d
# e
# d
#
# o
# n
#
# a
#
# n
# e
# w
#
# p
# o
# l
# i
# c
# y
# .
# H
# e
#
# h
# a
# d
#
# h
# i
# s
#
# s
# h
# i
# r
# t
#
# o
# n
#
# i
# n
# s
# i
# d
# e
#
# o
# u
# t
# .
# H
# e
#
# h
# a
# d
#
# h
# i
# s
#
# s
# o
# c
# k
# s
#
# o
# n
#
# i
# n
# s
# i
# d
# e
#
# o
# u
# t
# .
# H
# e
#
# h
# a
# d
#
# h
# i
# s
#
# s
# o
# c
# k
# s
#
# o
# n
#
# i
# n
# s
# i
# d
# e
#
# o
# u
# t
# .
# H
# e
#
# h
# a
# d
#
# n
# o
#
# l
# u
# c
# k
#
# i
# n
#
# f
# i
# n
# d
# i
# n
# g
#
# w
# o
# r
# k
# .
# H
# e
#
# h
# a
# d
#
# n
# o
#
# l
# u
# c
# k
#
# i
# n
#
# f
# i
# n
# d
# i
# n
# g
#
# w
# o
# r
# k
# .
# H
# e
#
# h
# a
# s
#
# a
#
# g
# o
# o
# d
#
# g
# r
# a
# s
# p
#
# o
# f
#
# E
# n
# g
# l
# i
# s
# h
# .
# H
# e
#
# h
# a
# s
#
# a
#
# l
# o
# t
#
# o
# f
#
# f
# o
# r
# e
# i
# g
# n
#
# s
# t
# a
# m
# p
# s
# .
# H
# e
#
# h
# a
# s
#
# a
#
# l
# o
# t
#
# o
# f
#
# o
# r
# i
# g
# i
# n
# a
# l
#
# i
# d
# e
# a
# s
# .
# H
# e
#
# h
# a
# s
#
# a
#
# s
# o
# n
#
# a
# n
# d
#
# t
# w
# o
#
# d
# a
# u
# g
# h
# t
# e
# r
# s
# .
# H
# e
#
# h
# a
# s
#
# a
#
# w
# o
# n
# d
# e
# r
# f
# u
# l
#
# p
# e
# r
# s
# o
# n
# a
# l
# i
# t
# y
# .
# H
# e
#
# h
# a
# s
#
# b
# e
# e
# n
#
# d
# e
# a
# d
#
# f
# o
# r
#
# t
# e
# n
#
# y
# e
# a
# r
# s
# .
# H
# e
#
# h
# a
# s
#
# b
# e
# e
# n
#
# i
# n
#
# H
# o
# k
# k
# a
# i
# d
# o
#
# b
# e
# f
# o
# r
# e
# .
# H
# e
#
# h
# a
# s
#
# d
# o
# z
# e
# n
# s
#
# o
# f
#
# E
# n
# g
# l
# i
# s
# h
#
# b
# o
# o
# k
# s
# .
# H
# e
#
# h
# a
# s
#
# j
# u
# s
# t
#
# b
# e
# c
# o
# m
# e
#
# a
#
# p
# r
# i
# n
# c
# i
# p
# a
# l
# .
# H
# e
#
# h
# a
# s
#
# l
# i
# v
# e
# d
#
# h
# e
# r
# e
#
# f
# o
# r
#
# o
# n
# e
#
# w
# e
# e
# k
# .
# H
# e
#
# h
# a
# s
#
# n
# o
#
# c
# h
# a
# n
# c
# e
#
# o
# f
#
# s
# u
# c
# c
# e
# e
# d
# i
# n
# g
# .
# H
# e
#
# h
# a
# s
#
# n
# o
#
# c
# h
# o
# i
# c
# e
#
# b
# u
# t
#
# t
# o
#
# r
# e
# s
# i
# g
# n
# .
# H
# e
#
# h
# a
# s
#
# n
# o
#
# i
# n
# t
# e
# r
# e
# s
# t
#
# i
# n
#
# p
# o
# l
# i
# t
# i
# c
# s
# .
# H
# e
#
# h
# a
# s
# n
# '
# t
#
# c
# o
# m
# e
#
# a
# l
# r
# e
# a
# d
# y
# ,
#
# h
# a
# s
#
# h
# e
# ?
# H
# e
#
# h
# e
# a
# r
# d
#
# t
# h
# e
#
# n
# e
# w
# s
#
# o
# n
#
# t
# h
# e
#
# r
# a
# d
# i
# o
# .
# H
# e
#
# h
# i
# d
#
# h
# i
# m
# s
# e
# l
# f
#
# b
# e
# h
# i
# n
# d
#
# t
# h
# e
#
# d
# o
# o
# r
# .
# H
# e
#
# h
# i
# t
#
# h
# i
# s
#
# h
# e
# a
# d
#
# a
# g
# a
# i
# n
# s
# t
#
# a
#
# r
# o
# c
# k
# .
# H
# e
#
# h
# i
# t
#
# h
# i
# s
#
# h
# e
# a
# d
#
# a
# g
# a
# i
# n
# s
# t
#
# a
#
# r
# o
# c
# k
# .
# H
# e
#
# i
# g
# n
# o
# r
# e
# d
#
# h
# i
# s
#
# f
# a
# t
# h
# e
# r
# '
# s
#
# a
# d
# v
# i
# c
# e
# .
# H
# e
#
# i
# s
#
# a
#
# f
# a
# m
# o
# u
# s
#
# b
# a
# s
# e
# b
# a
# l
# l
#
# p
# l
# a
# y
# e
# r
# .
# H
# e
#
# i
# s
#
# a
#
# v
# e
# r
# y
#
# t
# h
# o
# u
# g
# h
# t
# f
# u
# l
#
# p
# e
# r
# s
# o
# n
# .
# H
# e
#
# i
# s
#
# a
# b
# s
# e
# n
# t
#
# f
# r
# o
# m
#
# s
# c
# h
# o
# o
# l
#
# t
# o
# d
# a
# y
# .
# H
# e
#
# i
# s
#
# a
# f
# r
# a
# i
# d
#
# o
# f
#
# h
# i
# s
#
# o
# w
# n
#
# s
# h
# a
# d
# o
# w
# .
# H
# e
#
# i
# s
#
# a
# f
# r
# a
# i
# d
#
# o
# f
#
# h
# i
# s
#
# o
# w
# n
#
# s
# h
# a
# d
# o
# w
# .
# H
# e
#
# i
# s
#
# a
# l
# w
# a
# y
# s
#
# f
# o
# r
# g
# e
# t
# t
# i
# n
# g
#
# t
# h
# i
# n
# g
# s
# .
# H
# e
#
# i
# s
#
# f
# l
# y
# i
# n
# g
#
# t
# o
#
# P
# a
# r
# i
# s
#
# t
# o
# m
# o
# r
# r
# o
# w
# .
# H
# e
#
# i
# s
#
# l
# e
# a
# v
# i
# n
# g
#
# C
# h
# i
# c
# a
# g
# o
#
# t
# o
# m
# o
# r
# r
# o
# w
# .
# H
# e
#
# i
# s
#
# m
# u
# c
# h
#
# o
# l
# d
# e
# r
#
# t
# h
# a
# n
#
# h
# e
#
# l
# o
# o
# k
# s
# .
# H
# e
#
# i
# s
#
# o
# f
# t
# e
# n
#
# a
# b
# s
# e
# n
# t
#
# f
# r
# o
# m
#
# s
# c
# h
# o
# o
# l
# .
# H
# e
#
# i
# s
#
# t
# h
# e
#
# r
# i
# c
# h
# e
# s
# t
#
# m
# a
# n
#
# o
# n
#
# e
# a
# r
# t
# h
# .
# H
# e
#
# i
# s
#
# t
# o
#
# b
# l
# a
# m
# e
#
# f
# o
# r
#
# t
# h
# e
#
# f
# a
# i
# l
# u
# r
# e
# .
# H
# e
#
# i
# s
#
# t
# w
# o
#
# y
# e
# a
# r
# s
#
# o
# l
# d
# e
# r
#
# t
# h
# a
# n
#
# y
# o
# u
# .
# H
# e
#
# i
# s
#
# u
# s
# e
# d
#
# t
# o
#
# g
# e
# t
# t
# i
# n
# g
#
# u
# p
#
# e
# a
# r
# l
# y
# .
# H
# e
#
# i
# s
# n
# '
# t
#
# g
# o
# i
# n
# g
#
# t
# o
#
# b
# u
# y
#
# a
#
# c
# a
# m
# e
# r
# a
# .
# H
# e
#
# i
# s
# n
# '
# t
#
# h
# e
# r
# e
#
# b
# e
# c
# a
# u
# s
# e
#
# h
# e
# '
# s
#
# i
# l
# l
# .
# H
# e
#
# k
# e
# p
# t
#
# m
# e
#
# w
# a
# i
# t
# i
# n
# g
#
# a
# l
# l
#
# m
# o
# r
# n
# i
# n
# g
# .
# H
# e
#
# k
# e
# p
# t
#
# m
# e
#
# w
# a
# i
# t
# i
# n
# g
#
# f
# o
# r
#
# a
# n
#
# h
# o
# u
# r
# .
# H
# e
#
# k
# n
# o
# w
# s
#
# h
# o
# w
#
# t
# o
#
# p
# l
# a
# y
#
# t
# h
# e
#
# p
# i
# a
# n
# o
# .
# H
# e
#
# l
# e
# f
# t
#
# w
# i
# t
# h
# o
# u
# t
#
# s
# a
# y
# i
# n
# g
#
# g
# o
# o
# d
# b
# y
# e
# .
# H
# e
#
# l
# i
# k
# e
# s
#
# b
# o
# t
# h
#
# m
# u
# s
# i
# c
#
# a
# n
# d
#
# s
# p
# o
# r
# t
# s
# .
# H
# e
#
# l
# i
# k
# e
# s
#
# t
# o
#
# b
# u
# i
# l
# d
#
# m
# o
# d
# e
# l
#
# p
# l
# a
# n
# e
# s
# .
# H
# e
#
# l
# i
# v
# e
# d
#
# a
# b
# r
# o
# a
# d
#
# f
# o
# r
#
# m
# a
# n
# y
#
# y
# e
# a
# r
# s
# .
# H
# e
#
# l
# i
# v
# e
# s
#
# a
# l
# o
# n
# e
#
# i
# n
#
# a
# n
#
# a
# p
# a
# r
# t
# m
# e
# n
# t
# .
# H
# e
#
# l
# i
# v
# e
# s
#
# i
# n
#
# a
#
# w
# o
# r
# l
# d
#
# o
# f
#
# f
# a
# n
# t
# a
# s
# y
# .
# H
# e
#
# l
# o
# o
# k
# s
#
# o
# l
# d
# e
# r
#
# t
# h
# a
# n
#
# m
# y
#
# b
# r
# o
# t
# h
# e
# r
# .
# H
# e
#
# m
# a
# d
# e
#
# a
# n
#
# i
# m
# p
# o
# r
# t
# a
# n
# t
#
# d
# i
# s
# c
# o
# v
# e
# r
# y
# .
# H
# e
#
# m
# a
# j
# o
# r
# e
# d
#
# i
# n
#
# d
# r
# a
# m
# a
#
# a
# t
#
# c
# o
# l
# l
# e
# g
# e
# .
# H
# e
#
# m
# a
# k
# e
# s
#
# h
# i
# s
#
# l
# i
# v
# i
# n
# g
#
# b
# y
#
# s
# i
# n
# g
# i
# n
# g
# .
# H
# e
#
# m
# a
# y
#
# c
# o
# m
# e
#
# a
# n
# d
#
# s
# e
# e
#
# u
# s
#
# t
# o
# n
# i
# g
# h
# t
# .
# H
# e
#
# m
# a
# y
#
# c
# o
# m
# e
#
# t
# o
# m
# o
# r
# r
# o
# w
#
# a
# f
# t
# e
# r
# n
# o
# o
# n
# .
# H
# e
#
# p
# a
# i
# n
# t
# e
# d
#
# a
# l
# l
#
# t
# h
# e
#
# w
# a
# l
# l
# s
#
# g
# r
# e
# e
# n
# .
# H
# e
#
# p
# a
# i
# n
# t
# e
# d
#
# t
# h
# e
#
# d
# o
# o
# r
#
# o
# v
# e
# r
#
# w
# h
# i
# t
# e
# .
# H
# e
#
# p
# r
# a
# c
# t
# i
# c
# e
# d
#
# e
# v
# e
# r
# y
#
# d
# a
# y
#
# a
# t
#
# h
# o
# m
# e
# .
# H
# e
#
# p
# u
# s
# h
# e
# d
#
# t
# h
# e
#
# e
# m
# e
# r
# g
# e
# n
# c
# y
#
# b
# u
# t
# t
# o
# n
# .
# H
# e
#
# r
# a
# r
# e
# l
# y
#
# s
# t
# a
# y
# s
#
# h
# o
# m
# e
#
# o
# n
#
# S
# u
# n
# d
# a
# y
# .
# H
# e
#
# s
# a
# i
# d
#
# t
# h
# a
# t
#
# y
# o
# u
#
# h
# a
# d
#
# b
# e
# t
# t
# e
# r
#
# g
# o
# .
# H
# e
#
# s
# e
# l
# d
# o
# m
#
# w
# r
# i
# t
# e
# s
#
# t
# o
#
# h
# i
# s
#
# f
# a
# t
# h
# e
# r
# .
# H
# e
#
# s
# h
# o
# o
# k
#
# h
# a
# n
# d
# s
#
# w
# i
# t
# h
#
# h
# i
# s
#
# f
# r
# i
# e
# n
# d
# .
# H
# e
#
# s
# h
# o
# w
# e
# d
#
# i
# n
# t
# e
# r
# e
# s
# t
#
# i
# n
#
# t
# h
# e
#
# p
# l
# a
# n
# .
# H
# e
#
# s
# t
# a
# y
# e
# d
#
# t
# h
# e
# r
# e
#
# f
# o
# r
#
# t
# h
# r
# e
# e
#
# d
# a
# y
# s
# .
# H
# e
#
# s
# t
# o
# l
# e
#
# m
# o
# n
# e
# y
#
# f
# r
# o
# m
#
# h
# e
# r
#
# w
# a
# l
# l
# e
# t
# .
# H
# e
#
# t
# h
# r
# e
# w
#
# a
#
# b
# a
# l
# l
#
# o
# v
# e
# r
#
# t
# h
# e
#
# f
# e
# n
# c
# e
# .
# H
# e
#
# t
# h
# r
# e
# w
#
# a
#
# s
# t
# o
# n
# e
#
# i
# n
# t
# o
#
# t
# h
# e
#
# p
# o
# n
# d
# .
# H
# e
#
# t
# i
# p
# t
# o
# e
# d
#
# s
# o
#
# n
# o
#
# o
# n
# e
#
# h
# e
# a
# r
# d
#
# h
# i
# m
# .
# H
# e
#
# t
# o
# o
# k
#
# a
#
# p
# i
# c
# t
# u
# r
# e
#
# o
# f
#
# t
# h
# e
#
# k
# o
# a
# l
# a
# .
# H
# e
#
# t
# r
# a
# v
# e
# l
# e
# d
#
# a
# l
# l
#
# o
# v
# e
# r
#
# t
# h
# e
#
# w
# o
# r
# l
# d
# .
# H
# e
#
# t
# r
# a
# v
# e
# l
# e
# d
#
# a
# r
# o
# u
# n
# d
#
# t
# h
# e
#
# c
# o
# u
# n
# t
# r
# y
# .
# H
# e
#
# t
# r
# i
# e
# d
#
# s
# p
# e
# a
# k
# i
# n
# g
#
# F
# r
# e
# n
# c
# h
#
# t
# o
#
# u
# s
# .
# H
# e
#
# t
# r
# i
# e
# d
#
# t
# o
#
# s
# l
# e
# e
# p
#
# o
# n
#
# t
# h
# e
#
# f
# l
# o
# o
# r
# .
# H
# e
#
# t
# r
# i
# e
# d
#
# t
# o
#
# s
# p
# e
# a
# k
#
# F
# r
# e
# n
# c
# h
#
# t
# o
#
# u
# s
# .
# H
# e
#
# v
# i
# s
# i
# t
# e
# d
#
# h
# i
# s
#
# u
# n
# c
# l
# e
#
# y
# e
# s
# t
# e
# r
# d
# a
# y
# .
# H
# e
#
# w
# a
# l
# k
# s
#
# h
# i
# s
#
# d
# o
# g
#
# e
# v
# e
# r
# y
#
# m
# o
# r
# n
# i
# n
# g
# .
# H
# e
#
# w
# a
# n
# t
# s
#
# t
# o
#
# b
# e
#
# a
#
# t
# e
# n
# n
# i
# s
#
# p
# l
# a
# y
# e
# r
# .
# H
# e
#
# w
# a
# n
# t
# s
#
# t
# o
#
# w
# o
# r
# k
#
# i
# n
#
# a
#
# h
# o
# s
# p
# i
# t
# a
# l
# .
# H
# e
#
# w
# a
# s
#
# b
# o
# r
# n
#
# o
# n
#
# J
# u
# l
# y
#
# 2
# 8
# t
# h
# ,
#
# 1
# 8
# 8
# 8
# .
# H
# e
#
# w
# a
# s
#
# b
# r
# o
# u
# g
# h
# t
#
# u
# p
#
# b
# y
#
# h
# i
# s
#
# u
# n
# c
# l
# e
# .
# H
# e
#
# w
# a
# s
#
# b
# r
# o
# u
# g
# h
# t
#
# u
# p
#
# i
# n
#
# A
# u
# s
# t
# r
# a
# l
# i
# a
# .
# H
# e
#
# w
# a
# s
#
# d
# e
# t
# e
# r
# m
# i
# n
# e
# d
#
# t
# o
#
# g
# o
#
# a
# b
# r
# o
# a
# d
# .
# H
# e
#
# w
# a
# s
#
# f
# o
# r
# c
# e
# d
#
# t
# o
#
# w
# o
# r
# k
#
# o
# v
# e
# r
# t
# i
# m
# e
# .
# H
# e
#
# w
# a
# s
#
# i
# n
#
# A
# m
# e
# r
# i
# c
# a
#
# a
# t
#
# t
# h
# a
# t
#
# t
# i
# m
# e
# .
# H
# e
#
# w
# a
# s
#
# i
# n
# j
# u
# r
# e
# d
#
# i
# n
#
# t
# h
# e
#
# a
# c
# c
# i
# d
# e
# n
# t
# .
# H
# e
#
# w
# a
# s
#
# i
# n
# v
# o
# l
# v
# e
# d
#
# i
# n
#
# t
# h
# e
#
# t
# r
# o
# u
# b
# l
# e
# .
# H
# e
#
# w
# a
# s
#
# n
# o
# t
#
# a
# w
# a
# r
# e
#
# o
# f
#
# t
# h
# e
#
# d
# a
# n
# g
# e
# r
# .
# H
# e
#
# w
# a
# s
#
# s
# l
# e
# e
# p
# i
# n
# g
#
# u
# n
# d
# e
# r
#
# t
# h
# e
#
# t
# r
# e
# e
# .
# H
# e
#
# w
# a
# s
#
# t
# o
# o
#
# d
# r
# u
# n
# k
#
# t
# o
#
# d
# r
# i
# v
# e
#
# h
# o
# m
# e
# .
# H
# e
#
# w
# a
# s
#
# t
# o
# o
#
# y
# o
# u
# n
# g
#
# t
# o
#
# l
# i
# v
# e
#
# a
# l
# o
# n
# e
# .
# H
# e
#
# w
# a
# s
#
# w
# a
# i
# t
# i
# n
# g
#
# f
# o
# r
#
# a
#
# l
# o
# n
# g
#
# t
# i
# m
# e
# .
# H
# e
#
# w
# a
# s
#
# w
# o
# u
# n
# d
# e
# d
#
# i
# n
#
# t
# h
# e
#
# s
# h
# o
# u
# l
# d
# e
# r
# .
# H
# e
#
# w
# e
# a
# r
# s
#
# C
# h
# i
# n
# e
# s
# e
# -
# s
# t
# y
# l
# e
#
# c
# l
# o
# t
# h
# e
# s
# .
# H
# e
#
# w
# e
# n
# t
#
# t
# o
#
# s
# o
# m
# e
#
# p
# l
# a
# c
# e
#
# o
# r
#
# o
# t
# h
# e
# r
# .
# H
# e
#
# w
# i
# l
# l
#
# b
# e
#
# b
# a
# c
# k
#
# i
# n
#
# t
# e
# n
#
# m
# i
# n
# u
# t
# e
# s
# .
# H
# e
#
# w
# i
# l
# l
#
# b
# e
#
# c
# o
# m
# i
# n
# g
#
# t
# o
#
# t
# h
# e
#
# p
# a
# r
# t
# y
# .
# H
# e
#
# w
# i
# l
# l
#
# p
# l
# a
# y
#
# b
# a
# s
# e
# b
# a
# l
# l
#
# t
# o
# m
# o
# r
# r
# o
# w
# .
# H
# e
#
# w
# i
# l
# l
#
# r
# e
# a
# c
# h
#
# H
# a
# k
# o
# d
# a
# t
# e
#
# t
# o
# n
# i
# g
# h
# t
# .
# H
# e
#
# w
# o
# r
# k
# s
#
# a
# t
#
# t
# h
# e
#
# w
# e
# l
# f
# a
# r
# e
#
# o
# f
# f
# i
# c
# e
# .
# H
# e
#
# w
# o
# r
# k
# s
#
# f
# r
# o
# m
#
# M
# o
# n
# d
# a
# y
#
# t
# o
#
# F
# r
# i
# d
# a
# y
# .
# H
# e
#
# w
# o
# r
# k
# s
#
# w
# i
# t
# h
#
# m
# e
#
# a
# t
#
# t
# h
# e
#
# o
# f
# f
# i
# c
# e
# .
# H
# e
# '
# s
#
# a
#
# s
# t
# u
# d
# e
# n
# t
#
# a
# t
#
# t
# h
# i
# s
#
# c
# o
# l
# l
# e
# g
# e
# .
# H
# e
# '
# s
#
# a
# l
# w
# a
# y
# s
#
# a
# t
#
# h
# o
# m
# e
#
# o
# n
#
# S
# u
# n
# d
# a
# y
# s
# .
# H
# e
# '
# s
#
# i
# n
# t
# e
# r
# e
# s
# t
# e
# d
#
# i
# n
#
# m
# a
# n
# y
#
# t
# h
# i
# n
# g
# s
# .
# H
# e
# '
# s
#
# j
# u
# s
# t
#
# a
#
# b
# u
# s
# i
# n
# e
# s
# s
#
# a
# s
# s
# o
# c
# i
# a
# t
# e
# .
# H
# e
# '
# s
#
# p
# o
# p
# u
# l
# a
# r
#
# w
# i
# t
# h
#
# t
# h
# e
#
# s
# t
# u
# d
# e
# n
# t
# s
# .
# H
# e
# '
# s
#
# s
# i
# t
# t
# i
# n
# g
#
# a
# t
#
# a
# n
#
# e
# m
# p
# t
# y
#
# t
# a
# b
# l
# e
# .
# H
# e
# '
# s
#
# s
# t
# a
# r
# t
# e
# d
#
# l
# o
# o
# k
# i
# n
# g
#
# f
# o
# r
#
# a
#
# j
# o
# b
# .
# H
# e
# '
# s
#
# t
# h
# r
# e
# e
#
# y
# e
# a
# r
# s
#
# o
# l
# d
# e
# r
#
# t
# h
# a
# n
#
# m
# e
# .
# H
# e
# r
#
# h
# a
# i
# r
#
# i
# s
#
# l
# o
# n
# g
#
# a
# n
# d
#
# b
# e
# a
# u
# t
# i
# f
# u
# l
# .
# H
# e
# r
#
# h
# a
# i
# r
#
# i
# s
#
# s
# t
# r
# e
# a
# k
# e
# d
#
# w
# i
# t
# h
#
# g
# r
# a
# y
# .
# H
# e
# r
#
# h
# o
# b
# b
# y
#
# i
# s
#
# c
# o
# l
# l
# e
# c
# t
# i
# n
# g
#
# s
# t
# a
# m
# p
# s
# .
# H
# e
# r
#
# m
# o
# t
# h
# e
# r
#
# i
# s
#
# w
# r
# i
# t
# i
# n
# g
#
# a
#
# l
# e
# t
# t
# e
# r
# .
# H
# e
# r
#
# m
# o
# t
# h
# e
# r
#
# k
# n
# o
# c
# k
# e
# d
#
# o
# n
#
# t
# h
# e
#
# d
# o
# o
# r
# .
# H
# i
# s
#
# c
# l
# o
# t
# h
# e
# s
#
# a
# r
# e
#
# o
# u
# t
#
# o
# f
#
# f
# a
# s
# h
# i
# o
# n
# .
# H
# i
# s
#
# h
# o
# u
# s
# e
#
# i
# s
#
# a
# c
# r
# o
# s
# s
#
# t
# h
# e
#
# s
# t
# r
# e
# e
# t
# .
# H
# i
# s
#
# h
# o
# u
# s
# e
#
# i
# s
#
# n
# o
# t
#
# f
# a
# r
#
# f
# r
# o
# m
#
# h
# e
# r
# e
# .
# H
# i
# s
#
# m
# e
# t
# h
# o
# d
# s
#
# a
# r
# e
#
# n
# o
# t
#
# s
# c
# i
# e
# n
# t
# i
# f
# i
# c
# .
# H
# i
# s
#
# m
# o
# t
# h
# e
# r
#
# c
# a
# m
# e
#
# t
# o
#
# p
# i
# c
# k
#
# h
# i
# m
#
# u
# p
# .
# H
# i
# s
#
# m
# o
# t
# h
# e
# r
#
# u
# s
# e
# d
#
# t
# o
#
# b
# e
#
# a
#
# s
# i
# n
# g
# e
# r
# .
# H
# i
# s
#
# n
# e
# w
#
# n
# o
# v
# e
# l
#
# i
# s
#
# w
# o
# r
# t
# h
#
# r
# e
# a
# d
# i
# n
# g
# .
# H
# i
# s
#
# p
# o
# l
# i
# t
# i
# c
# a
# l
#
# c
# a
# r
# e
# e
# r
#
# h
# a
# s
#
# e
# n
# d
# e
# d
# .
# H
# i
# s
#
# r
# o
# o
# m
#
# w
# a
# s
#
# c
# o
# v
# e
# r
# e
# d
#
# w
# i
# t
# h
#
# d
# u
# s
# t
# .
# H
# o
# k
# k
# a
# i
# d
# o
#
# i
# s
#
# v
# e
# r
# y
#
# f
# a
# r
# ,
#
# i
# s
# n
# '
# t
#
# i
# t
# ?
# H
# o
# w
#
# a
# b
# o
# u
# t
#
# g
# o
# i
# n
# g
#
# o
# u
# t
#
# f
# o
# r
#
# a
#
# w
# a
# l
# k
# ?
# H
# o
# w
#
# a
# b
# o
# u
# t
#
# g
# o
# i
# n
# g
#
# o
# u
# t
#
# f
# o
# r
#
# d
# i
# n
# n
# e
# r
# ?
# H
# o
# w
#
# a
# b
# o
# u
# t
#
# s
# o
# m
# e
#
# m
# o
# r
# e
#
# r
# o
# a
# s
# t
#
# b
# e
# e
# f
# ?
# H
# o
# w
#
# d
# i
# d
#
# y
# o
# u
#
# c
# o
# m
# e
#
# b
# y
#
# t
# h
# i
# s
#
# m
# o
# n
# e
# y
# ?
# H
# o
# w
#
# d
# o
#
# y
# o
# u
#
# l
# i
# k
# e
#
# y
# o
# u
# r
#
# e
# g
# g
# s
#
# d
# o
# n
# e
# ?
# H
# o
# w
#
# d
# o
#
# y
# o
# u
#
# l
# i
# k
# e
#
# y
# o
# u
# r
#
# e
# g
# g
# s
#
# d
# o
# n
# e
# ?
# H
# o
# w
#
# d
# o
#
# y
# o
# u
#
# p
# r
# o
# n
# o
# u
# n
# c
# e
#
# t
# h
# i
# s
#
# w
# o
# r
# d
# ?
# H
# o
# w
#
# d
# o
#
# y
# o
# u
#
# p
# r
# o
# n
# o
# u
# n
# c
# e
#
# y
# o
# u
# r
#
# n
# a
# m
# e
# ?
# H
# o
# w
#
# l
# o
# n
# g
#
# a
# g
# o
#
# d
# i
# d
#
# t
# h
# e
#
# b
# u
# s
#
# l
# e
# a
# v
# e
# ?
# H
# o
# w
#
# l
# o
# n
# g
#
# h
# a
# v
# e
#
# y
# o
# u
#
# b
# e
# e
# n
#
# i
# n
#
# K
# o
# b
# e
# ?
# H
# o
# w
#
# l
# o
# n
# g
#
# h
# a
# v
# e
#
# y
# o
# u
#
# b
# e
# e
# n
#
# i
# n
#
# h
# e
# r
# e
# ?
# H
# o
# w
#
# l
# o
# n
# g
#
# i
# s
#
# t
# h
# e
#
# R
# a
# i
# n
# b
# o
# w
#
# B
# r
# i
# d
# g
# e
# ?
# H
# o
# w
#
# l
# o
# n
# g
#
# i
# s
#
# t
# h
# i
# s
#
# v
# i
# s
# a
#
# g
# o
# o
# d
#
# f
# o
# r
# ?
# H
# o
# w
#
# l
# o
# n
# g
#
# w
# i
# l
# l
#
# t
# h
# e
#
# m
# e
# e
# t
# i
# n
# g
#
# l
# a
# s
# t
# ?
# H
# o
# w
#
# m
# u
# c
# h
#
# i
# s
#
# t
# h
# a
# t
#
# m
# o
# u
# n
# t
# a
# i
# n
#
# b
# i
# k
# e
# ?
# H
# o
# w
#
# m
# u
# c
# h
#
# i
# s
#
# t
# h
# e
#
# r
# e
# n
# t
#
# p
# e
# r
#
# m
# o
# n
# t
# h
# ?
# H
# o
# w
#
# m
# u
# c
# h
#
# w
# a
# s
#
# y
# o
# u
# r
#
# n
# e
# w
#
# c
# o
# m
# p
# u
# t
# e
# r
# ?
# H
# o
# w
#
# s
# o
# o
# n
#
# c
# a
# n
#
# t
# h
# e
# y
#
# b
# e
#
# d
# e
# l
# i
# v
# e
# r
# e
# d
# ?
# I
#
# a
# c
# c
# o
# m
# p
# a
# n
# i
# e
# d
#
# h
# e
# r
#
# o
# n
#
# t
# h
# e
#
# p
# i
# a
# n
# o
# .
# I
#
# a
# g
# r
# e
# e
#
# w
# i
# t
# h
#
# h
# i
# m
#
# o
# n
#
# t
# h
# a
# t
#
# p
# o
# i
# n
# t
# .
# I
#
# a
# g
# r
# e
# e
#
# w
# i
# t
# h
#
# y
# o
# u
#
# o
# n
#
# t
# h
# i
# s
#
# i
# s
# s
# u
# e
# .

# %%
epochs=200

# %%
# 建立 encoder LSTM 隱藏層
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# 捨棄 output，只保留記憶狀態 h 及 c
encoder_states = [state_h, state_c]

# 建立 decoder LSTM 隱藏層
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# decoder 記憶狀態不會在訓練過程使用，只會在推論(Inference)使用
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# 定義模型，由 encoder_input_data 及 decoder_input_data 轉換為 decoder_target_data 
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# 訓練
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Out:
# Epoch 1/200
# 125/125 [==============================] - 17s 114ms/step - loss: 2.7130 - val_loss: 2.7733
# Epoch 2/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.2042 - val_loss: 2.7509
# Epoch 3/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1990 - val_loss: 2.7383
# Epoch 4/200
# 125/125 [==============================] - 13s 108ms/step - loss: 2.1860 - val_loss: 2.7307
# Epoch 5/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1807 - val_loss: 2.7312
# Epoch 6/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1725 - val_loss: 2.7277
# Epoch 7/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1617 - val_loss: 2.7286
# Epoch 8/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1745 - val_loss: 2.7286
# Epoch 9/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1716 - val_loss: 2.7282
# Epoch 10/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1634 - val_loss: 2.7275
# Epoch 11/200
# 125/125 [==============================] - 13s 106ms/step - loss: 2.1583 - val_loss: 2.7233
# Epoch 12/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1616 - val_loss: 2.7208
# Epoch 13/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1558 - val_loss: 2.7179
# Epoch 14/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1430 - val_loss: 2.7138
# Epoch 15/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1428 - val_loss: 2.7112
# Epoch 16/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1352 - val_loss: 2.7086
# Epoch 17/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1373 - val_loss: 2.7073
# Epoch 18/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1351 - val_loss: 2.7035
# Epoch 19/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1270 - val_loss: 2.6977
# Epoch 20/200
# 125/125 [==============================] - 13s 108ms/step - loss: 2.1204 - val_loss: 2.6989
# Epoch 21/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1182 - val_loss: 2.6979
# Epoch 22/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1300 - val_loss: 2.6957
# Epoch 23/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1140 - val_loss: 2.6919
# Epoch 24/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1200 - val_loss: 2.6891
# Epoch 25/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1099 - val_loss: 2.6874
# Epoch 26/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1041 - val_loss: 2.6867
# Epoch 27/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0984 - val_loss: 2.6838
# Epoch 28/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1075 - val_loss: 2.6824
# Epoch 29/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1030 - val_loss: 2.6829
# Epoch 30/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1015 - val_loss: 2.6812
# Epoch 31/200
# 125/125 [==============================] - 13s 108ms/step - loss: 2.1036 - val_loss: 2.6795
# Epoch 32/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0939 - val_loss: 2.6749
# Epoch 33/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1023 - val_loss: 2.6756
# Epoch 34/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.1007 - val_loss: 2.6736
# Epoch 35/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0975 - val_loss: 2.6706
# Epoch 36/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0931 - val_loss: 2.6673
# Epoch 37/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0852 - val_loss: 2.6680
# Epoch 38/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0831 - val_loss: 2.6672
# Epoch 39/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0744 - val_loss: 2.6603
# Epoch 40/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0850 - val_loss: 2.6598
# Epoch 41/200
# 125/125 [==============================] - 13s 108ms/step - loss: 2.0696 - val_loss: 2.6585
# Epoch 42/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0870 - val_loss: 2.6560
# Epoch 43/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0637 - val_loss: 2.6522
# Epoch 44/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0649 - val_loss: 2.6503
# Epoch 45/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0710 - val_loss: 2.6491
# Epoch 46/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0662 - val_loss: 2.6465
# Epoch 47/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0552 - val_loss: 2.6441
# Epoch 48/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0718 - val_loss: 2.6394
# Epoch 49/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0665 - val_loss: 2.6412
# Epoch 50/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0606 - val_loss: 2.6388
# Epoch 51/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0534 - val_loss: 2.6343
# Epoch 52/200
# 125/125 [==============================] - 13s 108ms/step - loss: 2.0538 - val_loss: 2.6339
# Epoch 53/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0523 - val_loss: 2.6315
# Epoch 54/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0425 - val_loss: 2.6313
# Epoch 55/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0422 - val_loss: 2.6277
# Epoch 56/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0516 - val_loss: 2.6262
# Epoch 57/200
# 125/125 [==============================] - 13s 108ms/step - loss: 2.0326 - val_loss: 2.6266
# Epoch 58/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0405 - val_loss: 2.6225
# Epoch 59/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0409 - val_loss: 2.6194
# Epoch 60/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0252 - val_loss: 2.6180
# Epoch 61/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0295 - val_loss: 2.6153
# Epoch 62/200
# 125/125 [==============================] - 13s 108ms/step - loss: 2.0330 - val_loss: 2.6128
# Epoch 63/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0295 - val_loss: 2.6146
# Epoch 64/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0310 - val_loss: 2.6101
# Epoch 65/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0131 - val_loss: 2.6067
# Epoch 66/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0129 - val_loss: 2.6050
# Epoch 67/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0098 - val_loss: 2.6048
# Epoch 68/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0173 - val_loss: 2.6034
# Epoch 69/200
# 125/125 [==============================] - 13s 108ms/step - loss: 2.0061 - val_loss: 2.5983
# Epoch 70/200
# 125/125 [==============================] - 13s 107ms/step - loss: 2.0107 - val_loss: 2.5969
# Epoch 71/200
# 125/125 [==============================] - 13s 107ms/step - loss: 1.9972 - val_loss: 2.5954
# Epoch 72/200
# 125/125 [==============================] - 13s 107ms/step - loss: 1.9967 - val_loss: 2.5941
# Epoch 73/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9962 - val_loss: 2.5899
# Epoch 74/200
# 125/125 [==============================] - 13s 107ms/step - loss: 1.9982 - val_loss: 2.5900
# Epoch 75/200
# 125/125 [==============================] - 13s 107ms/step - loss: 1.9894 - val_loss: 2.5883
# Epoch 76/200
# 125/125 [==============================] - 13s 107ms/step - loss: 1.9995 - val_loss: 2.5871
# Epoch 77/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9889 - val_loss: 2.5841
# Epoch 78/200
# 125/125 [==============================] - 13s 107ms/step - loss: 1.9945 - val_loss: 2.5842
# Epoch 79/200
# 125/125 [==============================] - 13s 107ms/step - loss: 1.9769 - val_loss: 2.5801
# Epoch 80/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9707 - val_loss: 2.5797
# Epoch 81/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9758 - val_loss: 2.5781
# Epoch 82/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9759 - val_loss: 2.5759
# Epoch 83/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9850 - val_loss: 2.5757
# Epoch 84/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9689 - val_loss: 2.5753
# Epoch 85/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9777 - val_loss: 2.5708
# Epoch 86/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9709 - val_loss: 2.5673
# Epoch 87/200
# 125/125 [==============================] - 13s 107ms/step - loss: 1.9515 - val_loss: 2.5639
# Epoch 88/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9593 - val_loss: 2.5638
# Epoch 89/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9602 - val_loss: 2.5608
# Epoch 90/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9607 - val_loss: 2.5616
# Epoch 91/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9407 - val_loss: 2.5584
# Epoch 92/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9396 - val_loss: 2.5568
# Epoch 93/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9522 - val_loss: 2.5553
# Epoch 94/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9399 - val_loss: 2.5525
# Epoch 95/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.9374 - val_loss: 2.5506
# Epoch 96/200
# 125/125 [==============================] - 13s 107ms/step - loss: 1.9279 - val_loss: 2.5485
# Epoch 97/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9426 - val_loss: 2.5496
# Epoch 98/200
# 125/125 [==============================] - 13s 107ms/step - loss: 1.9418 - val_loss: 2.5460
# Epoch 99/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9256 - val_loss: 2.5438
# Epoch 100/200
# 125/125 [==============================] - 13s 107ms/step - loss: 1.9280 - val_loss: 2.5426
# Epoch 101/200
# 125/125 [==============================] - 13s 107ms/step - loss: 1.9198 - val_loss: 2.5403
# Epoch 102/200
# 125/125 [==============================] - 13s 107ms/step - loss: 1.9198 - val_loss: 2.5384
# Epoch 103/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9307 - val_loss: 2.5399
# Epoch 104/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9158 - val_loss: 2.5360
# Epoch 105/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9164 - val_loss: 2.5335
# Epoch 106/200
# 125/125 [==============================] - 13s 107ms/step - loss: 1.9075 - val_loss: 2.5361
# Epoch 107/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9102 - val_loss: 2.5331
# Epoch 108/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9070 - val_loss: 2.5295
# Epoch 109/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9055 - val_loss: 2.5323
# Epoch 110/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.9072 - val_loss: 2.5287
# Epoch 111/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.9018 - val_loss: 2.5275
# Epoch 112/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8935 - val_loss: 2.5252
# Epoch 113/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8915 - val_loss: 2.5291
# Epoch 114/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8957 - val_loss: 2.5261
# Epoch 115/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8929 - val_loss: 2.5232
# Epoch 116/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8925 - val_loss: 2.5225
# Epoch 117/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8906 - val_loss: 2.5208
# Epoch 118/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8897 - val_loss: 2.5207
# Epoch 119/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8771 - val_loss: 2.5182
# Epoch 120/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8870 - val_loss: 2.5180
# Epoch 121/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8863 - val_loss: 2.5165
# Epoch 122/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8791 - val_loss: 2.5167
# Epoch 123/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8813 - val_loss: 2.5136
# Epoch 124/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8769 - val_loss: 2.5150
# Epoch 125/200
# 125/125 [==============================] - 13s 107ms/step - loss: 1.8815 - val_loss: 2.5148
# Epoch 126/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8733 - val_loss: 2.5124
# Epoch 127/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8864 - val_loss: 2.5117
# Epoch 128/200
# 125/125 [==============================] - 13s 107ms/step - loss: 1.8701 - val_loss: 2.5118
# Epoch 129/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8634 - val_loss: 2.5114
# Epoch 130/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8645 - val_loss: 2.5073
# Epoch 131/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8713 - val_loss: 2.5044
# Epoch 132/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8634 - val_loss: 2.5039
# Epoch 133/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8571 - val_loss: 2.5012
# Epoch 134/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8654 - val_loss: 2.5029
# Epoch 135/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.8515 - val_loss: 2.5020
# Epoch 136/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8615 - val_loss: 2.5002
# Epoch 137/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8547 - val_loss: 2.5007
# Epoch 138/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.8463 - val_loss: 2.4990
# Epoch 139/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8459 - val_loss: 2.4959
# Epoch 140/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8475 - val_loss: 2.4967
# Epoch 141/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.8470 - val_loss: 2.4954
# Epoch 142/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8546 - val_loss: 2.4943
# Epoch 143/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8471 - val_loss: 2.4933
# Epoch 144/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8401 - val_loss: 2.4934
# Epoch 145/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.8442 - val_loss: 2.4903
# Epoch 146/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8320 - val_loss: 2.4930
# Epoch 147/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8336 - val_loss: 2.4924
# Epoch 148/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.8263 - val_loss: 2.4888
# Epoch 149/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8383 - val_loss: 2.4893
# Epoch 150/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8525 - val_loss: 2.4889
# Epoch 151/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8244 - val_loss: 2.4850
# Epoch 152/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.8365 - val_loss: 2.4841
# Epoch 153/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8231 - val_loss: 2.4879
# Epoch 154/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8360 - val_loss: 2.4853
# Epoch 155/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8193 - val_loss: 2.4851
# Epoch 156/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8214 - val_loss: 2.4823
# Epoch 157/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8324 - val_loss: 2.4826
# Epoch 158/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8146 - val_loss: 2.4854
# Epoch 159/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8151 - val_loss: 2.4809
# Epoch 160/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8233 - val_loss: 2.4795
# Epoch 161/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.8169 - val_loss: 2.4813
# Epoch 162/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8079 - val_loss: 2.4756
# Epoch 163/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8058 - val_loss: 2.4790
# Epoch 164/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8014 - val_loss: 2.4756
# Epoch 165/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.8088 - val_loss: 2.4756
# Epoch 166/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.8019 - val_loss: 2.4771
# Epoch 167/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.8120 - val_loss: 2.4749
# Epoch 168/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8012 - val_loss: 2.4715
# Epoch 169/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.7958 - val_loss: 2.4698
# Epoch 170/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.7893 - val_loss: 2.4721
# Epoch 171/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.7974 - val_loss: 2.4725
# Epoch 172/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.7917 - val_loss: 2.4712
# Epoch 173/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.8058 - val_loss: 2.4698
# Epoch 174/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.7908 - val_loss: 2.4684
# Epoch 175/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.8046 - val_loss: 2.4717
# Epoch 176/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7945 - val_loss: 2.4667
# Epoch 177/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7809 - val_loss: 2.4645
# Epoch 178/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.7912 - val_loss: 2.4682
# Epoch 179/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.7777 - val_loss: 2.4642
# Epoch 180/200
# 125/125 [==============================] - 13s 108ms/step - loss: 1.7803 - val_loss: 2.4660
# Epoch 181/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7732 - val_loss: 2.4656
# Epoch 182/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7784 - val_loss: 2.4650
# Epoch 183/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7817 - val_loss: 2.4634
# Epoch 184/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7778 - val_loss: 2.4598
# Epoch 185/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.7755 - val_loss: 2.4623
# Epoch 186/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.7763 - val_loss: 2.4610
# Epoch 187/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7614 - val_loss: 2.4606
# Epoch 188/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7680 - val_loss: 2.4605
# Epoch 189/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7624 - val_loss: 2.4587
# Epoch 190/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7730 - val_loss: 2.4608
# Epoch 191/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7690 - val_loss: 2.4602
# Epoch 192/200
# 125/125 [==============================] - 14s 108ms/step - loss: 1.7621 - val_loss: 2.4607
# Epoch 193/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7645 - val_loss: 2.4573
# Epoch 194/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7641 - val_loss: 2.4599
# Epoch 195/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7612 - val_loss: 2.4574
# Epoch 196/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7501 - val_loss: 2.4558
# Epoch 197/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7508 - val_loss: 2.4563
# Epoch 198/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7503 - val_loss: 2.4571
# Epoch 199/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7585 - val_loss: 2.4532
# Epoch 200/200
# 125/125 [==============================] - 14s 109ms/step - loss: 1.7511 - val_loss: 2.4546

# %%
# 儲存模型及結果
#model.save('s2s.h5')

# %%
# 推論(Inference)
# 過程如下:
# 1) encode input and retrieve initial decoder state
# 2) run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token
# 3) Repeat with the current target token and current states

# 定義編碼器取樣模型
encoder_model = Model(encoder_inputs, encoder_states)

# 定義解碼器的input
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

# 定義解碼器 LSTM 模型
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
    
# 以編碼器的記憶狀態 h 及 c 為解碼器的記憶狀態  
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# 建立反向的 dict，才能透過查詢將數值轉回文字
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
# 模型預測，並取得翻譯結果(中文)    
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %% [markdown]
# ### testing predict

# %%
# 測試100次
for seq_index in range(100):
    # Take one sequence (part of the training test)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('*')
    print('Input sentence:', input_texts[seq_index])
    try:
        print('Decoded sentence:', decoded_sentence)
    except:
        # 出現亂碼，以?取代
        print('Decoded sentence:', decoded_sentence.encode('ascii', 'replace'))
        #print("error:", sys.exc_info()[0])
# Out:
# *
# Input sentence: Hi.
# Decoded sentence: 你。
#
# *
# Input sentence: Hi.
# Decoded sentence: 你。
#
# *
# Input sentence: Run.
# Decoded sentence: 你。
#
# *
# Input sentence: Wait!
# Decoded sentence: 它。
#
# *
# Input sentence: Hello!
# Decoded sentence: 它。
#
# *
# Input sentence: I try.
# Decoded sentence: 我的。
#
# *
# Input sentence: I won!
# Decoded sentence: 我的。
#
# *
# Input sentence: Oh no!
# Decoded sentence: 不不。。
#
# *
# Input sentence: Cheers!
# Decoded sentence: 抓麗。。
#
# *
# Input sentence: He ran.
# Decoded sentence: 他的。
#
# *
# Input sentence: Hop in.
# Decoded sentence: 你的。
#
# *
# Input sentence: I lost.
# Decoded sentence: 我在。。
#
# *
# Input sentence: I quit.
# Decoded sentence: 我的。
#
# *
# Input sentence: I'm OK.
# Decoded sentence: 我们。。
#
# *
# Input sentence: Listen.
# Decoded sentence: 請它。
#
# *
# Input sentence: No way!
# Decoded sentence: 它不。
#
# *
# Input sentence: No way!
# Decoded sentence: 它不。
#
# *
# Input sentence: Really?
# Decoded sentence: 你。。
#
# *
# Input sentence: Try it.
# Decoded sentence: 它不。。
#
# *
# Input sentence: We try.
# Decoded sentence: 我们们。
#
# *
# Input sentence: Why me?
# Decoded sentence: 你的有。。
#
# *
# Input sentence: Ask Tom.
# Decoded sentence: 汤姆姆。
#
# *
# Input sentence: Be calm.
# Decoded sentence: 抓續。。
#
# *
# Input sentence: Be fair.
# Decoded sentence: 腾了。
#
# *
# Input sentence: Be kind.
# Decoded sentence: 抓續。。
#
# *
# Input sentence: Be nice.
# Decoded sentence: 这是。。
#
# *
# Input sentence: Call me.
# Decoded sentence: 把它一。
#
# *
# Input sentence: Call us.
# Decoded sentence: 請要。。
#
# *
# Input sentence: Come in.
# Decoded sentence: 它是你。
#
# *
# Input sentence: Get Tom.
# Decoded sentence: 把这是一。。
#
# *
# Input sentence: Get out!
# Decoded sentence: 滾。
#
# *
# Input sentence: Go away!
# Decoded sentence: 滾。
#
# *
# Input sentence: Go away!
# Decoded sentence: 滾。
#
# *
# Input sentence: Go away.
# Decoded sentence: 把它。
#
# *
# Input sentence: Goodbye!
# Decoded sentence: 把它。
#
# *
# Input sentence: Goodbye!
# Decoded sentence: 把它。
#
# *
# Input sentence: Hang on!
# Decoded sentence: 它的。
#
# *
# Input sentence: He came.
# Decoded sentence: 他的。
#
# *
# Input sentence: He runs.
# Decoded sentence: 他是。。
#
# *
# Input sentence: Help me.
# Decoded sentence: 它是你。。
#
# *
# Input sentence: Hold on.
# Decoded sentence: 它是你。
#
# *
# Input sentence: Hug Tom.
# Decoded sentence: 汤姆姆。
#
# *
# Input sentence: I agree.
# Decoded sentence: 我的。
#
# *
# Input sentence: I'm ill.
# Decoded sentence: 我的。。
#
# *
# Input sentence: I'm old.
# Decoded sentence: 我的天。
#
# *
# Input sentence: It's OK.
# Decoded sentence: 它不。
#
# *
# Input sentence: It's me.
# Decoded sentence: 它是你。
#
# *
# Input sentence: Join us.
# Decoded sentence: 她的。。
#
# *
# Input sentence: Keep it.
# Decoded sentence: 抓續。。
#
# *
# Input sentence: Kiss me.
# Decoded sentence: 不要。。
#
# *
# Input sentence: Perfect!
# Decoded sentence: 抓姆。
#
# *
# Input sentence: See you.
# Decoded sentence: 它。。
#
# *
# Input sentence: Shut up!
# Decoded sentence: 滾。
#
# *
# Input sentence: Skip it.
# Decoded sentence: 别它。
#
# *
# Input sentence: Take it.
# Decoded sentence: 把燈。。
#
# *
# Input sentence: Wake up!
# Decoded sentence: 你。。
#
# *
# Input sentence: Wash up.
# Decoded sentence: 它是你。
#
# *
# Input sentence: We know.
# Decoded sentence: 我们们。
#
# *
# Input sentence: Welcome.
# Decoded sentence: 它是你。
#
# *
# Input sentence: Who won?
# Decoded sentence: 你的。
#
# *
# Input sentence: Why not?
# Decoded sentence: 你的。。
#
# *
# Input sentence: You run.
# Decoded sentence: 你你。
#
# *
# Input sentence: Back off.
# Decoded sentence: 抓姆。
#
# *
# Input sentence: Be still.
# Decoded sentence: 腾一。。
#
# *
# Input sentence: Cuff him.
# Decoded sentence: 把这是一個。。
#
# *
# Input sentence: Drive on.
# Decoded sentence: 它不。。
#
# *
# Input sentence: Get away!
# Decoded sentence: 滾。
#
# *
# Input sentence: Get away!
# Decoded sentence: 滾。
#
# *
# Input sentence: Get down!
# Decoded sentence: 滾。
#
# *
# Input sentence: Get lost!
# Decoded sentence: 滾。
#
# *
# Input sentence: Get real.
# Decoded sentence: 抓續。。
#
# *
# Input sentence: Grab Tom.
# Decoded sentence: 抓續。
#
# *
# Input sentence: Grab him.
# Decoded sentence: 抓續。。
#
# *
# Input sentence: Have fun.
# Decoded sentence: 这是你。
#
# *
# Input sentence: He tries.
# Decoded sentence: 他是。。
#
# *
# Input sentence: Humor me.
# Decoded sentence: 它是你。。
#
# *
# Input sentence: Hurry up.
# Decoded sentence: 你的。
#
# *
# Input sentence: Hurry up.
# Decoded sentence: 你的。
#
# *
# Input sentence: I forgot.
# Decoded sentence: 我在。。
#
# *
# Input sentence: I resign.
# Decoded sentence: 我的。
#
# *
# Input sentence: I'll pay.
# Decoded sentence: 我们的。。
#
# *
# Input sentence: I'm busy.
# Decoded sentence: 我的。
#
# *
# Input sentence: I'm cold.
# Decoded sentence: 我的。。
#
# *
# Input sentence: I'm fine.
# Decoded sentence: 我的不。
#
# *
# Input sentence: I'm full.
# Decoded sentence: 我在。。
#
# *
# Input sentence: I'm sick.
# Decoded sentence: 我的。。
#
# *
# Input sentence: I'm sick.
# Decoded sentence: 我的。。
#
# *
# Input sentence: Leave me.
# Decoded sentence: 讓我要。。
#
# *
# Input sentence: Let's go!
# Decoded sentence: 我不的。
#
# *
# Input sentence: Let's go!
# Decoded sentence: 我不的。
#
# *
# Input sentence: Let's go!
# Decoded sentence: 我不的。
#
# *
# Input sentence: Look out!
# Decoded sentence: 它。。
#
# *
# Input sentence: She runs.
# Decoded sentence: 她的她。
#
# *
# Input sentence: Stand up.
# Decoded sentence: 滾。
#
# *
# Input sentence: They won.
# Decoded sentence: 他們他。
#
# *
# Input sentence: Tom died.
# Decoded sentence: 汤姆有。
#
# *
# Input sentence: Tom quit.
# Decoded sentence: 汤姆有。。
#
# *
# Input sentence: Tom swam.
# Decoded sentence: 汤姆有。。
#
# *
# Input sentence: Trust me.
# Decoded sentence: 請不。
#
# *
# Input sentence: Try hard.
# Decoded sentence: 它是你。
